# %% [markdown]
# # Scraper (master)
# This notebook scrapes company data from urls found on glassdoor.com's [Browse Companies](https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=1&isHiringSurge=0) page in order to create a data base for our NLP_Diversity_and_Inclusion project.
#
# Data includes:
# - Company Name
# - Size
# - Headquarters location
# - Industry
# - Ratings given by employees *(Overall, Diversity & Inclusion, Culture & Values, Work/Life Balance, Senior Management, Compensation and Benefits, and Career Opportunities)*
# - Number of Reviews
# - Company Description
# - Mission Statement

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

import pandas as pd
import numpy as np
import time

# %% [markdown]
# **Setting up User-Agent to prevent ip block:**

# %%
#Setting driver and User-Agent to prevent ip block
    
opts = Options()
opts.add_argument("Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36")
#opts.add_argument('headless')

driver = webdriver.Chrome(options=opts)
time.sleep(5)

# %% [markdown]
# **DRIVER HERE:**

# %%
#start driver on main url, 
url_main = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=1&isHiringSurge=0' #main url

driver.get(url_main)
#time.sleep(10)

# %% [markdown]
# ## Scrapes
# Beginning from most recent scrape

# %% [markdown]
# ### Attept 8:

# %%
##8th try

unsuccessful_links8 = [] ##UPDATE## this line to create unique list for this scrape attempt
companies8 = [] ##UPDATE## this line to create unique list for this scrape attempt

def scraping_pages(num_pages):
    #Creating 'n' urls with url_roots to scrape
    url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
    nums = [x+290 for x in range(num_pages)] ##UPDATE## x + __ according to where last scrape attempt left off
    url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root 
    time.sleep(10) #give page plenty of time to load (page 1 loads first, then specified 'n' page)
    
    for u in url_mains:
        driver.get(u)
        time.sleep(10)
        
    #looking for 'Overview' links from each main search page
        elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
        company_links = []
        for elem in elems:
            company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
            if 'Overview' in company_link:
                company_links.append(company_link) #each company's 'Overview' link added to company_link list  
    
    #iterating through each company's "Overview" url
        for url in company_links:
            try: #fail safe for inevitable errors
                driver.get(url)
                time.sleep(5)

##---------------------------------------- Handling login ------------------------------------------##
                name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
                pw = 'pw'
                
                try: #login                    
                    username = driver.find_element_by_id("userEmail")
                    password = driver.find_element_by_id("userPassword")
                    submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
                    username.send_keys(name)
                    password.send_keys(pw)
                    submit.click()
                    time.sleep(4) #let page load
                except: #no login required
                    time.sleep(2)
                    pass

##---------------------------------- Gathering Variables - Main Page ---------------------------------##                                
                name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
                size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
                headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
                industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
                try:
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
                except: 
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

            #Gather Description - handling "Read More" button
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
                    read_more.click()
                    time.sleep(2)
                    description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
                except:
                    description = "N/A"

            #Gather Mission - handling "Read More" button    
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
                    read_more.click()
                    time.sleep(2)
                    mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
                except:
                    mission = "N/A"

##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
            #Webpage layout 1
                try: 
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
                    time.sleep(5) #let page load

                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
            #Webpage layout 2
                except: 
                    driver.get(url) #recalling url
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
                    time.sleep(5) #let page load
                    
                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
##---------------------------------------- Creating a Dictionary ----------------------------------------##
                companies8.append({ ##UPDATE## this line to create unique dictionary for this scrape attempt
                    "NAME" : name,
                    "SIZE" : size,
                    "LOCATION_HQ" : headquarters,
                    "INDUSTRY" : industry,
                    "RATING_OVERALL" : rating_overall,
                    "RATING_DI" : rating_DI,
                    "RATING_CV" : rating_CV,
                    "RATING_WL" : rating_WL,
                    "RATING_SM" : rating_SM,
                    "RATING_CB" : rating_CB,
                    "RATING_CO" : rating_CO,
                    "NUM_REVIEWS" : num_reviews,
                    "DESCRIPTION" : description,
                    "MISSION" : mission
                                 })

            except: #fail safe for inevitable errors
                unsuccessful_links8.append(url) #adding unsuccessful urls to a list ##UPDATE## unsuccessful_links list
                print('ERROR: ', url)
                time.sleep(10)
                
        print(f'Finished scraping {len(companies8)} companies') ##UPDATE## companies list name
        df8 = pd.DataFrame(companies8)                          ##UPDATE## df number and companies list name
    return df8                                                  ##UPDATE## df number

# %%
scraping_pages(100)
# Out:
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Achievement-First-EI_IE297029.11,28.htm
# Finished scraping 9 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-American-Campus-Communities-EI_IE35177.11,38.htm
# Finished scraping 16 companies
# Finished scraping 25 companies
# Finished scraping 32 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-American-Campus-Communities-EI_IE35177.11,38.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Altran-EI_IE28187.11,17.htm
# Finished scraping 40 companies
# Finished scraping 47 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Beam-Suntory-EI_IE817030.11,23.htm
# Finished scraping 56 companies
# Finished scraping 64 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Natixis-EI_IE10682.11,18.htm
# Finished scraping 73 companies
# Finished scraping 83 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-GlobalLogic-EI_IE23009.11,22.htm
# Finished scraping 92 companies
# Finished scraping 101 companies
# Finished scraping 110 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Versiti-EI_IE1788941.11,18.htm
# Finished scraping 118 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Booking-com-EI_IE256653.11,22.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-CHOC-Children-s-EI_IE18961.11,26.htm
# Finished scraping 126 companies
# Finished scraping 136 companies
# Finished scraping 145 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Campbell-Soup-Company-EI_IE129.11,32.htm
# Finished scraping 152 companies
# Finished scraping 160 companies
# Finished scraping 167 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Thrive-Skilled-Pediatric-Care-EI_IE1673884.11,40.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-OU-Medicine-EI_IE121005.11,22.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Fanatics-EI_IE688277.11,19.htm
# Finished scraping 173 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Mindbody-EI_IE319289.11,19.htm
# Finished scraping 180 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Beckman-Coulter-EI_IE87.11,26.htm
# Finished scraping 188 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Mindbody-EI_IE319289.11,19.htm
# Finished scraping 195 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Granite-City-EI_IE11318.11,23.htm
# Finished scraping 204 companies
# Finished scraping 212 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-OU-Medicine-EI_IE121005.11,22.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Fanatics-EI_IE688277.11,19.htm
# Finished scraping 219 companies
# Finished scraping 227 companies
# Finished scraping 236 companies
# Finished scraping 245 companies
# Finished scraping 255 companies
# Finished scraping 264 companies
# Finished scraping 274 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cisco-Systems-EI_IE1425.11,24.htm
# Finished scraping 281 companies
# Finished scraping 291 companies
# Finished scraping 300 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Carilion-Clinic-EI_IE4669.11,26.htm
# Finished scraping 308 companies
# Finished scraping 317 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Ideal-Concepts-EI_IE972320.11,25.htm
# Finished scraping 325 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-University-of-Virginia-Health-System-EI_IE19755.11,47.htm
# Finished scraping 334 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cafe-Rio-Mexican-Grill-EI_IE29490.11,33.htm
# Finished scraping 343 companies
# Finished scraping 352 companies
# Finished scraping 361 companies
# Finished scraping 371 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Imperva-EI_IE101738.11,18.htm
# Finished scraping 380 companies
# Finished scraping 390 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Bonaventure-Senior-Living-EI_IE375095.11,36.htm
# Finished scraping 398 companies
# Finished scraping 408 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Mercy-Health-EI_IE631749.11,23.htm
# Finished scraping 416 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Albert-Einstein-Healthcare-Network-EI_IE17521.11,45.htm
# Finished scraping 425 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-UMass-Medical-School-EI_IE486626.11,31.htm
# Finished scraping 434 companies
# Finished scraping 443 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Alcoa-EI_IE29.11,16.htm
# Finished scraping 452 companies
# Finished scraping 462 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-UMass-Medical-School-EI_IE486626.11,31.htm
# Finished scraping 469 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Western-Union-EI_IE14655.11,24.htm
# Finished scraping 478 companies
# Finished scraping 488 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Seattle-Cancer-Care-Alliance-EI_IE111819.11,39.htm
# Finished scraping 495 companies
# Finished scraping 505 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Rooms-To-Go-EI_IE8574.11,22.htm
# Finished scraping 514 companies
# Finished scraping 524 companies
# Finished scraping 534 companies
# Finished scraping 544 companies
# Finished scraping 554 companies
# Finished scraping 564 companies
# Finished scraping 573 companies
# Finished scraping 583 companies
# Finished scraping 592 companies
# Finished scraping 600 companies
# Finished scraping 608 companies
# Finished scraping 616 companies
# Finished scraping 626 companies
# Finished scraping 634 companies
# Finished scraping 643 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-SCL-Health-EI_IE686780.11,21.htm
# Finished scraping 652 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Edgewell-Personal-Care-EI_IE1028523.11,33.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Konecranes-EI_IE38371.11,21.htm
# Finished scraping 659 companies
# Finished scraping 669 companies
# Finished scraping 679 companies
# Finished scraping 689 companies
# Finished scraping 698 companies
# Finished scraping 704 companies
# Finished scraping 713 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-City-National-Bank-EI_IE1266.11,29.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Carilion-Clinic-EI_IE4669.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Vertex-Pharmaceuticals-EI_IE2080.11,33.htm
# Finished scraping 720 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-NTT-Ltd-EI_IE12228.11,18.htm
# Finished scraping 729 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Great-Wolf-Lodge-EI_IE421051.11,27.htm
# Finished scraping 738 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Great-Wolf-Lodge-EI_IE421051.11,27.htm
# Finished scraping 746 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-University-of-Virginia-Health-System-EI_IE19755.11,47.htm
# Finished scraping 755 companies
# Finished scraping 765 companies
# Finished scraping 775 companies
# Finished scraping 785 companies
# Finished scraping 794 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Famous-Footwear-EI_IE925237.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Imperva-EI_IE101738.11,18.htm
# Finished scraping 801 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cedar-Point-Amusement-Park-EI_IE558009.11,37.htm
# Finished scraping 810 companies
# Finished scraping 820 companies
# Finished scraping 828 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Mercy-Health-EI_IE631749.11,23.htm
# Finished scraping 835 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Qlik-EI_IE354111.11,15.htm
# Finished scraping 844 companies
# Finished scraping 854 companies
# Finished scraping 863 companies
# Finished scraping 873 companies
#                                      NAME                    SIZE  \
# 0                    Travis County, Texas  1001 to 5000 Employees
# 1          bareMinerals\nPart of Shiseido  1001 to 5000 Employees
# 2     Valley Medical Center\nHiring Surge  1001 to 5000 Employees
# 3                                      2U  1001 to 5000 Employees
# 4                St. Joseph Health System        10000+ Employees
# ..                                    ...                     ...
# 868                                 Valeo        10000+ Employees
# 869                                   TVA        10000+ Employees
# 870                     Dierbergs Markets  1001 to 5000 Employees
# 871                        Deckers Brands  1001 to 5000 Employees
# 872  First American Financial Corporation        10000+ Employees
#
#            LOCATION_HQ                                 INDUSTRY  \
# 0           Austin, TX                    Municipal Governments
# 1    San Francisco, CA     Beauty & Personal Accessories Stores
# 2           Renton, WA         Health Care Services & Hospitals
# 3           Lanham, MD  Enterprise Software & Network Solutions
# 4           Irvine, CA         Health Care Services & Hospitals
# ..                 ...                                      ...
# 868      Paris, France   Transportation Equipment Manufacturing
# 869      Knoxville, TN                                   Energy
# 870   Chesterfield, MO            Grocery Stores & Supermarkets
# 871         Goleta, CA      Department, Clothing, & Shoe Stores
# 872      Santa Ana, CA                       Insurance Carriers
#
#     RATING_OVERALL RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB  \
# 0              3.8       3.3       3.4       3.7       3.2       3.7
# 1              3.9       4.3       4.3       3.7       3.6       3.5
# 2              3.8       3.6       3.6       3.6       3.1       4.5
# 3              3.9       3.9       3.9       3.9       3.4       3.6
# 4              3.7       3.4       3.6       3.5       3.2       3.4
# ..             ...       ...       ...       ...       ...       ...
# 868            3.6       3.9       3.4       3.0       2.9       3.5
# 869            3.6       3.6       3.3       3.8       3.0       4.1
# 870            3.6       3.8       3.3       3.5       3.6       2.5
# 871            3.6       4.0       3.9       3.7       3.2       3.5
# 872            3.6       4.1       3.8       3.7       3.3       3.4
#
#     RATING_CO            NUM_REVIEWS  \
# 0         3.4    See All 119 Reviews
# 1         3.1    See All 743 Reviews
# 2         3.6    See All 125 Reviews
# 3         3.5    See All 790 Reviews
# 4         3.5    See All 566 Reviews
# ..        ...                    ...
# 868       3.4  See All 2,492 Reviews
# 869       3.2    See All 378 Reviews
# 870       3.4    See All 209 Reviews
# 871       3.0    See All 293 Reviews
# 872       3.4  See All 1,256 Reviews
#
#                                            DESCRIPTION  \
# 0                                                  N/A
# 1    The foundation that launched the mineral makeu...
# 2    Valley Medical Center is the largest nonprofit...
# 3    2U, Inc. is a diverse collection of more than ...
# 4    Based in Irvine, Calif., St. Joseph Health ser...
# ..                                                 ...
# 868  Valeo is an automotive supplier, partner to al...
# 869  For more than eight decades, the Tennessee Val...
# 870  Discover your hometown career at the Hometown ...
# 871  Deckers Brands is a global leader in designing...
# 872  First American makes the dream of property own...
#
#                                                MISSION
# 0                                                  N/A
# 1                                                  N/A
# 2    Mission: Valley Medical Center, the District’s...
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 868                                                N/A
# 869  Mission: Mission:\nTVA was built for the peopl...
# 870                                                N/A
# 871                                                N/A
# 872                                                N/A
#
# [873 rows x 14 columns]

# %%
print(len(companies8))
print('unsuccessful: ', len(unsuccessful_links8))
unsuccessful_links8
# Out:
# 873
# unsuccessful:  50
# ['https://www.glassdoor.com/Overview/Working-at-Achievement-First-EI_IE297029.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-American-Campus-Communities-EI_IE35177.11,38.htm',
#  'https://www.glassdoor.com/Overview/Working-at-American-Campus-Communities-EI_IE35177.11,38.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Altran-EI_IE28187.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Beam-Suntory-EI_IE817030.11,23.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Natixis-EI_IE10682.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-GlobalLogic-EI_IE23009.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Versiti-EI_IE1788941.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Booking-com-EI_IE256653.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-CHOC-Children-s-EI_IE18961.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Campbell-Soup-Company-EI_IE129.11,32.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Thrive-Skilled-Pediatric-Care-EI_IE1673884.11,40.htm',
#  'https://www.glassdoor.com/Overview/Working-at-OU-Medicine-EI_IE121005.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Fanatics-EI_IE688277.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Mindbody-EI_IE319289.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Beckman-Coulter-EI_IE87.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Mindbody-EI_IE319289.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Granite-City-EI_IE11318.11,23.htm',
#  'https://www.glassdoor.com/Overview/Working-at-OU-Medicine-EI_IE121005.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Fanatics-EI_IE688277.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cisco-Systems-EI_IE1425.11,24.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Carilion-Clinic-EI_IE4669.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Ideal-Concepts-EI_IE972320.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-University-of-Virginia-Health-System-EI_IE19755.11,47.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cafe-Rio-Mexican-Grill-EI_IE29490.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Imperva-EI_IE101738.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Bonaventure-Senior-Living-EI_IE375095.11,36.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Mercy-Health-EI_IE631749.11,23.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Albert-Einstein-Healthcare-Network-EI_IE17521.11,45.htm',
#  'https://www.glassdoor.com/Overview/Working-at-UMass-Medical-School-EI_IE486626.11,31.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Alcoa-EI_IE29.11,16.htm',
#  'https://www.glassdoor.com/Overview/Working-at-UMass-Medical-School-EI_IE486626.11,31.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Western-Union-EI_IE14655.11,24.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Seattle-Cancer-Care-Alliance-EI_IE111819.11,39.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Rooms-To-Go-EI_IE8574.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-SCL-Health-EI_IE686780.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Edgewell-Personal-Care-EI_IE1028523.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Konecranes-EI_IE38371.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-City-National-Bank-EI_IE1266.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Carilion-Clinic-EI_IE4669.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Vertex-Pharmaceuticals-EI_IE2080.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-NTT-Ltd-EI_IE12228.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Great-Wolf-Lodge-EI_IE421051.11,27.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Great-Wolf-Lodge-EI_IE421051.11,27.htm',
#  'https://www.glassdoor.com/Overview/Working-at-University-of-Virginia-Health-System-EI_IE19755.11,47.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Famous-Footwear-EI_IE925237.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Imperva-EI_IE101738.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cedar-Point-Amusement-Park-EI_IE558009.11,37.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Mercy-Health-EI_IE631749.11,23.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Qlik-EI_IE354111.11,15.htm']

# %%
##renaming df with len(companies)
df8_873 = pd.DataFrame(companies8) ##############################################################
df8_873
# Out:
#                                      NAME                    SIZE  \
# 0                    Travis County, Texas  1001 to 5000 Employees
# 1          bareMinerals\nPart of Shiseido  1001 to 5000 Employees
# 2     Valley Medical Center\nHiring Surge  1001 to 5000 Employees
# 3                                      2U  1001 to 5000 Employees
# 4                St. Joseph Health System        10000+ Employees
# ..                                    ...                     ...
# 868                                 Valeo        10000+ Employees
# 869                                   TVA        10000+ Employees
# 870                     Dierbergs Markets  1001 to 5000 Employees
# 871                        Deckers Brands  1001 to 5000 Employees
# 872  First American Financial Corporation        10000+ Employees
#
#            LOCATION_HQ                                 INDUSTRY  \
# 0           Austin, TX                    Municipal Governments
# 1    San Francisco, CA     Beauty & Personal Accessories Stores
# 2           Renton, WA         Health Care Services & Hospitals
# 3           Lanham, MD  Enterprise Software & Network Solutions
# 4           Irvine, CA         Health Care Services & Hospitals
# ..                 ...                                      ...
# 868      Paris, France   Transportation Equipment Manufacturing
# 869      Knoxville, TN                                   Energy
# 870   Chesterfield, MO            Grocery Stores & Supermarkets
# 871         Goleta, CA      Department, Clothing, & Shoe Stores
# 872      Santa Ana, CA                       Insurance Carriers
#
#     RATING_OVERALL RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB  \
# 0              3.8       3.3       3.4       3.7       3.2       3.7
# 1              3.9       4.3       4.3       3.7       3.6       3.5
# 2              3.8       3.6       3.6       3.6       3.1       4.5
# 3              3.9       3.9       3.9       3.9       3.4       3.6
# 4              3.7       3.4       3.6       3.5       3.2       3.4
# ..             ...       ...       ...       ...       ...       ...
# 868            3.6       3.9       3.4       3.0       2.9       3.5
# 869            3.6       3.6       3.3       3.8       3.0       4.1
# 870            3.6       3.8       3.3       3.5       3.6       2.5
# 871            3.6       4.0       3.9       3.7       3.2       3.5
# 872            3.6       4.1       3.8       3.7       3.3       3.4
#
#     RATING_CO            NUM_REVIEWS  \
# 0         3.4    See All 119 Reviews
# 1         3.1    See All 743 Reviews
# 2         3.6    See All 125 Reviews
# 3         3.5    See All 790 Reviews
# 4         3.5    See All 566 Reviews
# ..        ...                    ...
# 868       3.4  See All 2,492 Reviews
# 869       3.2    See All 378 Reviews
# 870       3.4    See All 209 Reviews
# 871       3.0    See All 293 Reviews
# 872       3.4  See All 1,256 Reviews
#
#                                            DESCRIPTION  \
# 0                                                  N/A
# 1    The foundation that launched the mineral makeu...
# 2    Valley Medical Center is the largest nonprofit...
# 3    2U, Inc. is a diverse collection of more than ...
# 4    Based in Irvine, Calif., St. Joseph Health ser...
# ..                                                 ...
# 868  Valeo is an automotive supplier, partner to al...
# 869  For more than eight decades, the Tennessee Val...
# 870  Discover your hometown career at the Hometown ...
# 871  Deckers Brands is a global leader in designing...
# 872  First American makes the dream of property own...
#
#                                                MISSION
# 0                                                  N/A
# 1                                                  N/A
# 2    Mission: Valley Medical Center, the District’s...
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 868                                                N/A
# 869  Mission: Mission:\nTVA was built for the peopl...
# 870                                                N/A
# 871                                                N/A
# 872                                                N/A
#
# [873 rows x 14 columns]

# %%
df_csv8 = df8_873.to_csv('glassdoor_ratings8_873.csv', index=False) #######################

# %%
driver.close()
driver.quit()
#scraper stopped at 390

# %% [markdown]
# #### Attept 7:

# %%
##7th try

unsuccessful_links7 = [] ###############################################
companies7 = [] ########################################################

def scraping_pages(num_pages):
    #Creating 'n' urls with url_roots to scrape
    url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
    nums = [x+234 for x in range(num_pages)] ####################################################################
    url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root 
    time.sleep(10) #give page plenty of time to load (page 1 loads first, then specified 'n' page)
    
    for u in url_mains:
        driver.get(u)
        time.sleep(10)
        
    #looking for 'Overview' links from each main search page
        elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
        company_links = []
        for elem in elems:
            company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
            if 'Overview' in company_link:
                company_links.append(company_link) #each company's 'Overview' link added to company_link list  
    
    #iterating through each company's "Overview" url
        for url in company_links:
            try: #fail safe for inevitable errors
                driver.get(url)
                time.sleep(5)

##---------------------------------------- Handling login ------------------------------------------##
                name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
                pw = 'pw'
                
                try: #login                    
                    username = driver.find_element_by_id("userEmail")
                    password = driver.find_element_by_id("userPassword")
                    submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
                    username.send_keys(name)
                    password.send_keys(pw)
                    submit.click()
                    time.sleep(4) #let page load
                except: #no login required
                    time.sleep(2) #########do we need this much time?
                    pass

##---------------------------------- Gathering Variables - Main Page ---------------------------------##                                
                name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
                size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
                headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
                industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
                try:
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
                except: 
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

            #Gather Description - handling "Read More" button
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
                    read_more.click()
                    time.sleep(2)
                    description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
                except:
                    description = "N/A"

            #Gather Mission - handling "Read More" button    
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
                    read_more.click()
                    time.sleep(2)
                    mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
                except:
                    mission = "N/A"

##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
            #Webpage layout 1
                try: 
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
                    time.sleep(5) #let page load

                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
            #Webpage layout 2
                except: 
                    driver.get(url) #recalling url
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
                    time.sleep(5) #let page load
                    
                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
##---------------------------------------- Creating a Dictionary ----------------------------------------##
                companies7.append({ ###############################################
                    "NAME" : name,
                    "SIZE" : size,
                    "LOCATION_HQ" : headquarters,
                    "INDUSTRY" : industry,
                    "RATING_OVERALL" : rating_overall,
                    "RATING_DI" : rating_DI,
                    "RATING_CV" : rating_CV,
                    "RATING_WL" : rating_WL,
                    "RATING_SM" : rating_SM,
                    "RATING_CB" : rating_CB,
                    "RATING_CO" : rating_CO,
                    "NUM_REVIEWS" : num_reviews,
                    "DESCRIPTION" : description,
                    "MISSION" : mission
                                 })

            except: #fail safe for inevitable errors
                unsuccessful_links7.append(url) #adding unsuccessful urls to a list ###############
                print('ERROR: ', url)
                time.sleep(10)
                
        print(f'Finished scraping {len(companies7)} companies') ###################
        df7 = pd.DataFrame(companies7) ############################################
    return df7 ####################################################################

# %%
scraping_pages(100)
# Out:
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Progrexion-EI_IE396304.11,21.htm
# Finished scraping 8 companies
# Finished scraping 18 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Mutual-of-Omaha-EI_IE3678.11,26.htm
# Finished scraping 26 companies
# Finished scraping 36 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-GEP-EI_IE238741.11,14.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Progrexion-EI_IE396304.11,21.htm
# Finished scraping 42 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Progrexion-EI_IE396304.11,21.htm
# Finished scraping 51 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-NXP-Semiconductors-EI_IE13528.11,29.htm
# Finished scraping 60 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Otter-Products-EI_IE372107.11,25.htm
# Finished scraping 68 companies
# Finished scraping 77 companies
# Finished scraping 87 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-NXP-Semiconductors-EI_IE13528.11,29.htm
# Finished scraping 95 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Relativity-EI_IE1771815.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sonoco-Products-EI_IE1890.11,26.htm
# Finished scraping 102 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Republic-National-Distributing-Company-EI_IE253796.11,49.htm
# Finished scraping 111 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Christie-s-EI_IE10292.11,21.htm
# Finished scraping 120 companies
# Finished scraping 130 companies
# Finished scraping 140 companies
# Finished scraping 149 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Lenovo-EI_IE8034.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Southland-Industries-EI_IE5661.11,31.htm
# Finished scraping 157 companies
# Finished scraping 166 companies
# Finished scraping 175 companies
# Finished scraping 182 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Kings-Dominion-EI_IE249376.11,25.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-FM-Global-EI_IE15259.11,20.htm
# Finished scraping 190 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Samsung-Semiconductor-Inc-US-EI_IE19069.11,39.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Tenaris-EI_IE15805.11,18.htm
# Finished scraping 196 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Tenaris-EI_IE15805.11,18.htm
# Finished scraping 205 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Samsung-Semiconductor-Inc-US-EI_IE19069.11,39.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Tenaris-EI_IE15805.11,18.htm
# Finished scraping 213 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Texas-Health-Resources-EI_IE7647.11,33.htm
# Finished scraping 222 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Texas-Health-Resources-EI_IE7647.11,33.htm
# Finished scraping 231 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Texas-Health-Resources-EI_IE7647.11,33.htm
# Finished scraping 238 companies
# Finished scraping 248 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-GAF-EI_IE17770.11,14.htm
# Finished scraping 257 companies
# Finished scraping 266 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Otsuka-EI_IE290418.11,17.htm
# Finished scraping 273 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-WE-Communications-EI_IE3817.11,28.htm
# Finished scraping 280 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Restaurant-Brands-International-EI_IE1138188.11,42.htm
# Finished scraping 286 companies
# Finished scraping 294 companies
# Finished scraping 303 companies
# Finished scraping 312 companies
# Finished scraping 319 companies
# Finished scraping 327 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-CareFirst-BlueCross-BlueShield-EI_IE269607.11,41.htm
# Finished scraping 333 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Plymouth-Rock-Assurance-EI_IE26532.11,34.htm
# Finished scraping 339 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Plymouth-Rock-Assurance-EI_IE26532.11,34.htm
# Finished scraping 347 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Plymouth-Rock-Assurance-EI_IE26532.11,34.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Hibu-EI_IE7640.11,15.htm
# Finished scraping 354 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Hibu-EI_IE7640.11,15.htm
# Finished scraping 361 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Babies-R-Us-EI_IE683121.11,22.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-84-Lumber-EI_IE2696.11,20.htm
# Finished scraping 369 companies
# Finished scraping 375 companies
# Finished scraping 384 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Avery-Dennison-EI_IE65.11,25.htm
# Finished scraping 393 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cox-Automotive-EI_IE981845.11,25.htm
# Finished scraping 402 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Shoe-Carnival-EI_IE36.11,24.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Biltmore-Company-EI_IE33626.11,27.htm
# Finished scraping 409 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cox-Automotive-EI_IE981845.11,25.htm
# Finished scraping 417 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Curacao-EI_IE669178.11,18.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Saint-Gobain-Performance-Plastics-EI_IE224539.11,44.htm
# Finished scraping 423 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Blackboard-EI_IE11113.11,21.htm
# Finished scraping 432 companies
# Finished scraping 440 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Saint-Gobain-Performance-Plastics-EI_IE224539.11,44.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Achievement-First-EI_IE297029.11,28.htm
# Finished scraping 447 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Skadden-Arps-Slate-Meagher-and-Flom-EI_IE3381.11,46.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sweetwater-EI_IE3402.11,21.htm
# Finished scraping 454 companies
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-118-2336b4016c16> in <module>()
# ----> 1 scraping_pages(100)
#
# <ipython-input-117-63dad2466be3> in scraping_pages(num_pages)
#      12
#      13     for u in url_mains:
# ---> 14         driver.get(u)
#      15         time.sleep(10)
#      16
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=88.0.4324.150)

# %%
print(len(companies7))
print('unsuccessful: ', len(unsuccessful_links7))
unsuccessful_links7
# Out:
# 454
# unsuccessful:  48
# ['https://www.glassdoor.com/Overview/Working-at-Progrexion-EI_IE396304.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Mutual-of-Omaha-EI_IE3678.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-GEP-EI_IE238741.11,14.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Progrexion-EI_IE396304.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Progrexion-EI_IE396304.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-NXP-Semiconductors-EI_IE13528.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Otter-Products-EI_IE372107.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-NXP-Semiconductors-EI_IE13528.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Relativity-EI_IE1771815.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Sonoco-Products-EI_IE1890.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Republic-National-Distributing-Company-EI_IE253796.11,49.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Christie-s-EI_IE10292.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Lenovo-EI_IE8034.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Southland-Industries-EI_IE5661.11,31.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Kings-Dominion-EI_IE249376.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-FM-Global-EI_IE15259.11,20.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Samsung-Semiconductor-Inc-US-EI_IE19069.11,39.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Tenaris-EI_IE15805.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Tenaris-EI_IE15805.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Samsung-Semiconductor-Inc-US-EI_IE19069.11,39.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Tenaris-EI_IE15805.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Texas-Health-Resources-EI_IE7647.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Texas-Health-Resources-EI_IE7647.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Texas-Health-Resources-EI_IE7647.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-GAF-EI_IE17770.11,14.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Otsuka-EI_IE290418.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-WE-Communications-EI_IE3817.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Restaurant-Brands-International-EI_IE1138188.11,42.htm',
#  'https://www.glassdoor.com/Overview/Working-at-CareFirst-BlueCross-BlueShield-EI_IE269607.11,41.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Plymouth-Rock-Assurance-EI_IE26532.11,34.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Plymouth-Rock-Assurance-EI_IE26532.11,34.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Plymouth-Rock-Assurance-EI_IE26532.11,34.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Hibu-EI_IE7640.11,15.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Hibu-EI_IE7640.11,15.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Babies-R-Us-EI_IE683121.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-84-Lumber-EI_IE2696.11,20.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Avery-Dennison-EI_IE65.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cox-Automotive-EI_IE981845.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Shoe-Carnival-EI_IE36.11,24.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Biltmore-Company-EI_IE33626.11,27.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cox-Automotive-EI_IE981845.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Curacao-EI_IE669178.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Saint-Gobain-Performance-Plastics-EI_IE224539.11,44.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Blackboard-EI_IE11113.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Saint-Gobain-Performance-Plastics-EI_IE224539.11,44.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Achievement-First-EI_IE297029.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Skadden-Arps-Slate-Meagher-and-Flom-EI_IE3381.11,46.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Sweetwater-EI_IE3402.11,21.htm']

# %%
df7_453 = pd.DataFrame(companies7) ##############################################################
df7_453
# Out:
#                                             NAME                     SIZE  \
# 0                                 Torchy's Tacos   1001 to 5000 Employees
# 1                   Loma Linda University Health         10000+ Employees
# 2                                             F5  5001 to 10000 Employees
# 3                      Oakley\nPart of Luxottica   1001 to 5000 Employees
# 4                                  St. Dominic's   1001 to 5000 Employees
# ..                                           ...                      ...
# 449                                    dressbarn         10000+ Employees
# 450  JLG Industries\nPart of Oshkosh Corporation   1001 to 5000 Employees
# 451               CallidusCloud\nAcquired by SAP   1001 to 5000 Employees
# 452                    Chevron Phillips Chemical  5001 to 10000 Employees
# 453                              Henkels & McCoy   1001 to 5000 Employees
#
#              LOCATION_HQ                                 INDUSTRY  \
# 0             Austin, TX                       Casual Restaurants
# 1         Loma Linda, CA         Health Care Services & Hospitals
# 2            Seattle, WA             Computer Hardware & Software
# 3     Foothill Ranch, CA          Consumer Products Manufacturing
# 4            Jackson, MS         Health Care Services & Hospitals
# ..                   ...                                      ...
# 449           Mahwah, NJ      Department, Clothing, & Shoe Stores
# 450  Mc Connellsburg, PA                 Industrial Manufacturing
# 451           Dublin, CA  Enterprise Software & Network Solutions
# 452    The Woodlands, TX                   Chemical Manufacturing
# 453        Blue Bell, PA                             Construction
#
#     RATING_OVERALL RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB  \
# 0              3.9       4.6       4.1       3.7       3.4       3.3
# 1              3.8       3.6       3.8       3.6       3.0       3.3
# 2              3.9       4.2       4.0       4.0       3.6       4.2
# 3              3.9       4.1       4.0       3.9       3.4       3.4
# 4              4.0       4.5       4.1       3.5       3.3       3.5
# ..             ...       ...       ...       ...       ...       ...
# 449            3.8       2.7       3.7       3.6       3.0       3.0
# 450            3.9       3.2       4.0       3.6       3.3       4.1
# 451            3.8       4.7       3.7       3.5       3.4       3.7
# 452            3.8       3.1       3.5       3.6       2.9       3.9
# 453            3.8       3.5       3.7       3.0       3.2       3.5
#
#     RATING_CO            NUM_REVIEWS  \
# 0         3.5    See All 199 Reviews
# 1         3.5    See All 440 Reviews
# 2         3.6  See All 1,002 Reviews
# 3         2.8    See All 713 Reviews
# 4         3.4    See All 126 Reviews
# ..        ...                    ...
# 449       2.8    See All 781 Reviews
# 450       3.8    See All 211 Reviews
# 451       3.6    See All 270 Reviews
# 452       3.0    See All 253 Reviews
# 453       3.2    See All 185 Reviews
#
#                                            DESCRIPTION  \
# 0    The Torchy's legacy began in Austin, Texas in ...
# 1    Loma Linda University Medical Center (LLUMC) o...
# 2    Today, business is about people, applications,...
# 3    Oakley sells so many sunglasses, it goggles th...
# 4    Since 1946, when the Dominican Sisters operate...
# ..                                                 ...
# 449  At dressbarn, in everything we do, we inspire ...
# 450  JLG Industries, Inc. is the world’s leading de...
# 451  CallidusCloud, now part of SAP, is the global ...
# 452  You may not realize it, but you’ve likely used...
# 453  Founded in 1923, Henkels & McCoy, Inc., is a p...
#
#                                                MISSION
# 0                                                  N/A
# 1                                                  N/A
# 2    Mission: F5 (NASDAQ: FFIV) gives the world’s l...
# 3                                                  N/A
# 4    Mission: St. Dominic’s recognizes its basic pa...
# ..                                                 ...
# 449                                                N/A
# 450                                                N/A
# 451                                                N/A
# 452                                                N/A
# 453                                                N/A
#
# [454 rows x 14 columns]

# %%
df_csv7_453 = df7_453.to_csv('glassdoor_ratings7_453.csv', index=False) #######################

# %%
driver.close()
driver.quit()
#stopped at page 290

# %% [markdown]
# #### Attept 6:

# %%
##6th try

unsuccessful_links6 = [] ###############################################
companies6 = [] ########################################################

def scraping_pages(num_pages):
    #Creating 'n' urls with url_roots to scrape
    url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
    nums = [x+134 for x in range(num_pages)] ############################################################
    url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root 
    time.sleep(10) #give page plenty of time to load (page 1 loads first, then specified 'n' page)
    
    for u in url_mains:
        driver.get(u)
        time.sleep(5)
        
    #looking for 'Overview' links from each main search page
        elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
        company_links = []
        for elem in elems:
            company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
            if 'Overview' in company_link:
                company_links.append(company_link) #each company's 'Overview' link added to company_link list  
    
    #iterating through each company's "Overview" url
        for url in company_links:
            try: #fail safe for inevitable errors
                driver.get(url)
                time.sleep(5)

##---------------------------------------- Handling login ------------------------------------------##
                name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
                pw = 'pw'
                
                try: #login                    
                    username = driver.find_element_by_id("userEmail")
                    password = driver.find_element_by_id("userPassword")
                    submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
                    username.send_keys(name)
                    password.send_keys(pw)
                    submit.click()
                    time.sleep(4) #let page load
                except: #no login required
                    time.sleep(2) #########do we need this much time?
                    pass

##---------------------------------- Gathering Variables - Main Page ---------------------------------##                                
                name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
                size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
                headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
                industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
                try:
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
                except: 
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

            #Gather Description - handling "Read More" button
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
                    read_more.click()
                    time.sleep(2)
                    description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
                except:
                    description = "N/A"

            #Gather Mission - handling "Read More" button    
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
                    read_more.click()
                    time.sleep(2)
                    mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
                except:
                    mission = "N/A"

##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
            #Webpage layout 1
                try: 
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
                    time.sleep(5) #let page load

                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
            #Webpage layout 2
                except: 
                    driver.get(url) #recalling url
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
                    time.sleep(5) #let page load
                    
                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
##---------------------------------------- Creating a Dictionary ----------------------------------------##
                companies6.append({ ###############################################
                    "NAME" : name,
                    "SIZE" : size,
                    "LOCATION_HQ" : headquarters,
                    "INDUSTRY" : industry,
                    "RATING_OVERALL" : rating_overall,
                    "RATING_DI" : rating_DI,
                    "RATING_CV" : rating_CV,
                    "RATING_WL" : rating_WL,
                    "RATING_SM" : rating_SM,
                    "RATING_CB" : rating_CB,
                    "RATING_CO" : rating_CO,
                    "NUM_REVIEWS" : num_reviews,
                    "DESCRIPTION" : description,
                    "MISSION" : mission
                                 })

            except: #fail safe for inevitable errors
                unsuccessful_links6.append(url) #adding unsuccessful urls to a list ###############
                print('ERROR: ', url)
                time.sleep(10)
                
        print(f'Finished scraping {len(companies6)} companies') ###################
        df6 = pd.DataFrame(companies6) ######################################################################
    return df6 ##############################################################################################

# %%
scraping_pages(100)
# Out:
# Finished scraping 10 companies
# Finished scraping 20 companies
# Finished scraping 30 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Twilio-EI_IE410790.11,17.htm
# Finished scraping 37 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Twilio-EI_IE410790.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Blue-Cross-Blue-Shield-of-Massachusetts-EI_IE6294.11,50.htm
# Finished scraping 45 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-American-Fidelity-Assurance-Company-EI_IE17535.11,46.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Blue-Cross-Blue-Shield-of-Massachusetts-EI_IE6294.11,50.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Great-American-Insurance-Group-EI_IE38078.11,41.htm
# Finished scraping 51 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Colgate-Palmolive-EI_IE162.11,28.htm
# Finished scraping 59 companies
# Finished scraping 67 companies
# Finished scraping 76 companies
# Finished scraping 85 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Infostretch-EI_IE268709.11,22.htm
# Finished scraping 92 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-InterSystems-EI_IE6282.11,23.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-National-Agents-Alliance-EI_IE225028.11,35.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Infostretch-EI_IE268709.11,22.htm
# Finished scraping 99 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-InterSystems-EI_IE6282.11,23.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Alvarez-and-Marsal-EI_IE16369.11,29.htm
# Finished scraping 107 companies
# Finished scraping 117 companies
# Finished scraping 127 companies
# Finished scraping 137 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Infoblox-EI_IE35108.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Kimball-Midwest-EI_IE238356.11,26.htm
# Finished scraping 145 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Alief-ISD-EI_IE116929.11,20.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Kimball-Midwest-EI_IE238356.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Scotts-Miracle-Gro-EI_IE1443.11,29.htm
# Finished scraping 150 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Infoblox-EI_IE35108.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Brightview-Senior-Living-EI_IE486610.11,35.htm
# Finished scraping 156 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-ZoomInfo-EI_IE22253.11,19.htm
# Finished scraping 165 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Seagen-EI_IE12902.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Airbus-EI_IE3059.11,17.htm
# Finished scraping 171 companies
# Finished scraping 179 companies
# Finished scraping 189 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-North-American-Lighting-EI_IE22490.11,34.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-U-S-Government-Accountability-Office-EI_IE41594.11,47.htm
# Finished scraping 197 companies
# Finished scraping 207 companies
# Finished scraping 216 companies
# Finished scraping 226 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-AdventHealth-Tampa-EI_IE700693.11,29.htm
# Finished scraping 234 companies
# Finished scraping 244 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Ciena-EI_IE6612.11,16.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Arup-EI_IE31809.11,15.htm
# Finished scraping 252 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Arup-EI_IE31809.11,15.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-UMass-Memorial-Health-Care-EI_IE122082.11,37.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Schlitterbahn-EI_IE472581.11,24.htm
# Finished scraping 258 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Schlitterbahn-EI_IE472581.11,24.htm
# Finished scraping 267 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Arm-EI_IE7834.11,14.htm
# Finished scraping 276 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Hiscox-EI_IE18106.11,17.htm
# Finished scraping 284 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Press-Ganey-EI_IE35100.11,22.htm
# Finished scraping 293 companies
# Finished scraping 303 companies
# Finished scraping 313 companies
# Finished scraping 321 companies
# Finished scraping 331 companies
# Finished scraping 341 companies
# Finished scraping 351 companies
# Finished scraping 361 companies
# Finished scraping 371 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Burke-Williams-EI_IE311485.11,25.htm
# Finished scraping 379 companies
# Finished scraping 388 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Rosendin-EI_IE3617.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-The-Hanover-Insurance-Group-EI_IE3664.11,38.htm
# Finished scraping 396 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Rosendin-EI_IE3617.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-The-Hanover-Insurance-Group-EI_IE3664.11,38.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Wrike-EI_IE420969.11,16.htm
# Finished scraping 403 companies
# Finished scraping 411 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-WatchGuard-Technologies-EI_IE9255.11,34.htm
# Finished scraping 420 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Trend-Micro-EI_IE8983.11,22.htm
# Finished scraping 429 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Trend-Micro-EI_IE8983.11,22.htm
# Finished scraping 437 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Keck-Medicine-of-USC-EI_IE720042.11,31.htm
# Finished scraping 444 companies
# Finished scraping 453 companies
# Finished scraping 463 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Boys-Town-EI_IE223815.11,20.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-SkyWest-Airlines-EI_IE1883.11,27.htm
# Finished scraping 469 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Boys-Town-EI_IE223815.11,20.htm
# Finished scraping 477 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Criteo-EI_IE426672.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-RS-and-H-EI_IE154426.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sony-Electronics-EI_IE19973.11,27.htm
# Finished scraping 484 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Vertex-Pennsylvania-EI_IE28981.11,30.htm
# Finished scraping 492 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-RS-and-H-EI_IE154426.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-SCP-Health-EI_IE229893.11,21.htm
# Finished scraping 500 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-SCP-Health-EI_IE229893.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Vertex-Pennsylvania-EI_IE28981.11,30.htm
# Finished scraping 507 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Tufts-Health-Plan-EI_IE6286.11,28.htm
# Finished scraping 516 companies
# Finished scraping 524 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-BMC-Software-EI_IE1160.11,23.htm
# Finished scraping 533 companies
# Finished scraping 543 companies
# Finished scraping 553 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Exelon-EI_IE526.11,17.htm
# Finished scraping 562 companies
# Finished scraping 571 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Vonage-EI_IE23019.11,17.htm
# Finished scraping 580 companies
# Finished scraping 590 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cook-Children-s-Health-Care-System-EI_IE18973.11,45.htm
# Finished scraping 599 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cook-Children-s-Health-Care-System-EI_IE18973.11,45.htm
# Finished scraping 607 companies
# Finished scraping 617 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sovos-EI_IE972182.11,16.htm
# Finished scraping 626 companies
# Finished scraping 633 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-The-Aerospace-Corporation-EI_IE5634.11,36.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-ASML-EI_IE5781.11,15.htm
# Finished scraping 640 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-UW-Health-EI_IE721652.11,20.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-The-Aerospace-Corporation-EI_IE5634.11,36.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-ASML-EI_IE5781.11,15.htm
# Finished scraping 647 companies
# Finished scraping 657 companies
# Finished scraping 667 companies
# Finished scraping 667 companies
# Finished scraping 676 companies
# Finished scraping 684 companies
# Finished scraping 694 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-First-Republic-Bank-EI_IE859.11,30.htm
# Finished scraping 703 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Match-EI_IE15905.11,16.htm
# Finished scraping 712 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Match-EI_IE15905.11,16.htm
# Finished scraping 719 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Anaplan-EI_IE695685.11,18.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Philz-Coffee-EI_IE311692.11,23.htm
# Finished scraping 726 companies
# Finished scraping 736 companies
# Finished scraping 746 companies
# Finished scraping 754 companies
# Finished scraping 764 companies
# Finished scraping 772 companies
# Finished scraping 780 companies
# Finished scraping 789 companies
# Finished scraping 798 companies
# Finished scraping 806 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-MSCI-EI_IE14616.11,15.htm
# Finished scraping 813 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Dental-Care-Alliance-EI_IE235849.11,31.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-CUNY-City-University-of-New-York-EI_IE3726.11,43.htm
# Finished scraping 821 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-MSCI-EI_IE14616.11,15.htm
# Finished scraping 830 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-CUNY-City-University-of-New-York-EI_IE3726.11,43.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Continental-EI_IE3768.11,22.htm
# Finished scraping 838 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-CUNY-City-University-of-New-York-EI_IE3726.11,43.htm
# Finished scraping 846 companies
#                                  NAME                     SIZE  \
# 0    Rockstar Games\nPart of Take-Two   1001 to 5000 Employees
# 1       National Renewable Energy Lab   1001 to 5000 Employees
# 2                FirstLight Home Care   1001 to 5000 Employees
# 3                             ManTech  5001 to 10000 Employees
# 4                              MedVet   1001 to 5000 Employees
# ..                                ...                      ...
# 841                   Protective Life   1001 to 5000 Employees
# 842                        Legg Mason   1001 to 5000 Employees
# 843                    Johns Manville  5001 to 10000 Employees
# 844                              PATH   1001 to 5000 Employees
# 845                               CSC   1001 to 5000 Employees
#
#          LOCATION_HQ                               INDUSTRY RATING_OVERALL  \
# 0       New York, NY                            Video Games            4.3
# 1         Golden, CO                                 Energy            4.3
# 2     Cincinnati, OH       Health Care Services & Hospitals            4.3
# 3        Herndon, VA                 Research & Development            4.3
# 4    Worthington, OH                    Veterinary Services            4.3
# ..               ...                                    ...            ...
# 841   Birmingham, AL                     Insurance Carriers            3.9
# 842    Baltimore, MD  Investment Banking & Asset Management            3.9
# 843       Denver, CO            Miscellaneous Manufacturing            3.9
# 844      Seattle, WA                      Social Assistance            3.9
# 845   Wilmington, DE                             Consulting            3.9
#
#     RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB RATING_CO  \
# 0         4.7       4.4       4.0       4.0       4.3       3.9
# 1         4.6       4.5       4.3       4.0       4.1       4.1
# 2         4.0       4.3       4.1       4.2       3.7       4.0
# 3         4.3       4.2       4.3       4.1       4.3       4.2
# 4         4.2       4.3       3.7       4.1       4.2       4.2
# ..        ...       ...       ...       ...       ...       ...
# 841       3.8       3.9       4.1       3.6       4.1       3.7
# 842       4.0       3.8       4.1       3.4       4.0       3.1
# 843       3.7       3.5       3.5       3.3       4.1       3.4
# 844       4.1       4.1       4.0       3.5       4.0       3.7
# 845       4.1       4.0       4.0       3.6       3.4       3.6
#
#                NUM_REVIEWS                                        DESCRIPTION  \
# 0      See All 236 Reviews  Rockstar Games doesn't see why only the kids s...
# 1      See All 370 Reviews  The National Renewable Energy Laboratory (NREL...
# 2      See All 251 Reviews  FirstLight Home Care is a leading provider of ...
# 3    See All 1,005 Reviews  ManTech was founded in 1968 to provide advance...
# 4      See All 214 Reviews  MedVet, with headquarters in Columbus, Ohio, i...
# ..                     ...                                                ...
# 841    See All 257 Reviews  We are a growing company with a bright future....
# 842    See All 195 Reviews  Legg Mason has served investors for over 110 y...
# 843    See All 213 Reviews  Johns Manville is a proud member of the Berksh...
# 844    See All 231 Reviews  PATH is a global organization that works to ac...
# 845    See All 414 Reviews  CSC® is the world's leading provider of busine...
#
#                                                MISSION
# 0                                                  N/A
# 1    Mission: Our emphasis is on a comprehensive en...
# 2    Mission: The FirstLight Home Care mission is r...
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 841                                                N/A
# 842                                                N/A
# 843                                                N/A
# 844                                                N/A
# 845  Mission: Between 2010 and 2015, CSC doubled in...
#
# [846 rows x 14 columns]

# %%
print(len(companies6))
print('unsuccessful: ', len(unsuccessful_links6))
unsuccessful_links6
# Out:
# 846
# unsuccessful:  80
# ['https://www.glassdoor.com/Overview/Working-at-Twilio-EI_IE410790.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Twilio-EI_IE410790.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Blue-Cross-Blue-Shield-of-Massachusetts-EI_IE6294.11,50.htm',
#  'https://www.glassdoor.com/Overview/Working-at-American-Fidelity-Assurance-Company-EI_IE17535.11,46.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Blue-Cross-Blue-Shield-of-Massachusetts-EI_IE6294.11,50.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Great-American-Insurance-Group-EI_IE38078.11,41.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Colgate-Palmolive-EI_IE162.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Infostretch-EI_IE268709.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-InterSystems-EI_IE6282.11,23.htm',
#  'https://www.glassdoor.com/Overview/Working-at-National-Agents-Alliance-EI_IE225028.11,35.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Infostretch-EI_IE268709.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-InterSystems-EI_IE6282.11,23.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Alvarez-and-Marsal-EI_IE16369.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Infoblox-EI_IE35108.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Kimball-Midwest-EI_IE238356.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-
# ..                                                 ...
# 841                                                N/A
# 842                                                N/A
# 843                                                N/A
# 844                                                N/A
# 845  Mission: Between 2010 and 2015, CSC doubled in...
#
# [846 rows x 14 columns]

# %%
df_csv6 = df6_846.to_csv('glassdoor_ratings6_846.csv', index=False)

# %% [markdown]
# **CLOSE DRIVER:**

# %%
driver.close()
driver.quit()
#made it to page 233

# %% [markdown]
# #### Attept 5:

# %%
##5th try

unsuccessful_links5 = []
companies5 = []

def scraping_pages(num_pages):
    #Creating 'n' urls with url_roots to scrape
    url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
    nums = [x+21 for x in range(num_pages)] 
    url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root
    
    for u in url_mains:
        driver.get(u)
            
    #looking for 'Overview' links from each main search page
        elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
        company_links = []
        for elem in elems:
            company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
            if 'Overview' in company_link:
                company_links.append(company_link) #each company's 'Overview' link added to company_link list  

        for url in company_links:
            try: #fail safe for inevitable errors
                driver.get(url)
                time.sleep(10)

##---------------------------------------- Handling login ------------------------------------------##
                name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
                pw = 'pw'
                
                try: #login                    
                    username = driver.find_element_by_id("userEmail")
                    password = driver.find_element_by_id("userPassword")
                    submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
                    username.send_keys(name)
                    password.send_keys(pw)
                    submit.click()
                    time.sleep(6) #lettin page load
                except: #no login required
                    pass

##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
                time.sleep(6)
                name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
                size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
                headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
                industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
                try:
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
                except: 
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

            #Gather Description - handling "Read More" button
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
                    read_more.click()
                    time.sleep(2)
                    description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
                except:
                    description = "N/A"

            #Gather Mission - handling "Read More" button    
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
                    read_more.click()
                    time.sleep(2)
                    mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
                except:
                    mission = "N/A"

##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
            #Webpage layout 1
                try: 
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
                    time.sleep(5) #let page load

                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
            #Webpage layout 2
                except: 
                    driver.get(url) #recalling url
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
                    time.sleep(5) #let page load
                    
                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
##---------------------------------------- Creating a Dictionary ----------------------------------------##
                companies5.append({
                    "NAME" : name,
                    "SIZE" : size,
                    "LOCATION_HQ" : headquarters,
                    "INDUSTRY" : industry,
                    "RATING_OVERALL" : rating_overall,
                    "RATING_DI" : rating_DI,
                    "RATING_CV" : rating_CV,
                    "RATING_WL" : rating_WL,
                    "RATING_SM" : rating_SM,
                    "RATING_CB" : rating_CB,
                    "RATING_CO" : rating_CO,
                    "NUM_REVIEWS" : num_reviews,
                    "DESCRIPTION" : description,
                    "MISSION" : mission
                                 })

            except: #fail safe for inevitable errors
                unsuccessful_links5.append(url) #adding unsuccessful urls to a list
                print('ERROR: ', url)
                time.sleep(10)
                
        print(f'Finished scraping {len(companies5)} companies')
        dfoops = pd.DataFrame(companies5)
    return dfoops

# %%
scraping_pages(130)
# Out:
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Texas-Instruments-EI_IE651.11,28.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Nokia-EI_IE3494.11,16.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Schneider-Electric-EI_IE3956.11,29.htm
# Finished scraping 7 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Memorial-Sloan-Kettering-EI_IE4711.11,35.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-NYU-Langone-Health-EI_IE121521.11,29.htm
# Finished scraping 14 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Airbnb-EI_IE391850.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-NYU-Langone-Health-EI_IE121521.11,29.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-United-Airlines-EI_IE683.11,26.htm
# Finished scraping 21 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-LexisNexis-Legal-and-Professional-EI_IE4146.11,44.htm
# Finished scraping 30 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-IHS-Markit-EI_IE1337673.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cengage-EI_IE20055.11,18.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Northwell-Health-EI_IE1142964.11,27.htm
# Finished scraping 36 companies
# Finished scraping 46 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Raising-Cane-s-EI_IE134590.11,25.htm
# Finished scraping 55 companies
# Finished scraping 65 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-T-Mobile-EI_IE9302.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Trane-Technologies-EI_IE349.11,29.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Boehringer-Ingelheim-EI_IE10416.11,31.htm
# Finished scraping 72 companies
# Finished scraping 82 companies
# Finished scraping 92 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Ericsson-Worldwide-EI_IE3472.11,29.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cargill-EI_IE2739.11,18.htm
# Finished scraping 100 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-OHSU-EI_IE23783.11,15.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Express-Employment-Professionals-EI_IE11188.11,43.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Juniper-Networks-EI_IE7224.11,27.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Amgen-EI_IE1130.11,16.htm
# Finished scraping 106 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Express-Employment-Professionals-EI_IE11188.11,43.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Juniper-Networks-EI_IE7224.11,27.htm
# Finished scraping 114 companies
# Finished scraping 122 companies
# Finished scraping 132 companies
# Finished scraping 141 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-UniFirst-EI_IE688.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Infor-EI_IE15375.11,16.htm
# Finished scraping 149 companies
# Finished scraping 158 companies
# Finished scraping 168 companies
# Finished scraping 177 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cellular-Sales-EI_IE152005.11,25.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Leidos-EI_IE730545.11,17.htm
# Finished scraping 185 companies
# Finished scraping 195 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Prudential-EI_IE2944.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Kellogg-Company-EI_IE377.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-General-Dynamics-Mission-Systems-EI_IE941740.11,43.htm
# Finished scraping 202 companies
# Finished scraping 212 companies
# Finished scraping 222 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Esri-EI_IE4043.11,15.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-IQVIA-EI_IE8347.11,16.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Aflac-EI_IE1302.11,16.htm
# Finished scraping 229 companies
# Finished scraping 239 companies
# Finished scraping 249 companies
# Finished scraping 259 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-BJC-HealthCare-EI_IE4650.11,25.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-BBVA-EI_IE1237.11,15.htm
# Finished scraping 265 companies
# Finished scraping 265 companies
# Finished scraping 275 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sephora-EI_IE14590.11,18.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Thermo-Fisher-Scientific-EI_IE658.11,35.htm
# Finished scraping 283 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-BAE-Systems-USA-EI_IE18934.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Honeywell-EI_IE28.11,20.htm
# Finished scraping 290 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Honeywell-EI_IE28.11,20.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Avaya-EI_IE12121.11,16.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Rackspace-Technology-EI_IE11783.11,31.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-DICK-S-Sporting-Goods-EI_IE8666.11,32.htm
# Finished scraping 296 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-McKesson-EI_IE434.11,19.htm
# Finished scraping 303 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Intermountain-Healthcare-EI_IE2842.11,35.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Gap-Inc-EI_IE1070099.11,18.htm
# Finished scraping 311 companies
# Finished scraping 321 companies
# Finished scraping 331 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-US-Department-of-Veterans-Affairs-EI_IE41429.11,44.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-ALDI-EI_IE7337.11,15.htm
# Finished scraping 339 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-AIG-EI_IE40.11,14.htm
# Finished scraping 348 companies
# Finished scraping 348 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Harbor-Freight-Tools-EI_IE241635.11,31.htm
# Finished scraping 357 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Publicis-Sapient-EI_IE1646026.11,27.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Quest-Diagnostics-EI_IE6655.11,28.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Encompass-Health-EI_IE1959649.11,27.htm
# Finished scraping 364 companies
# Finished scraping 364 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-UPMC-EI_IE14679.11,15.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Red-Ventures-EI_IE142090.11,23.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Chipotle-EI_IE15228.11,19.htm
# Finished scraping 371 companies
# Finished scraping 381 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-FedEx-Ground-EI_IE16846.11,23.htm
# Finished scraping 390 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-MITRE-EI_IE3976.11,16.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-HCA-Healthcare-EI_IE2062.11,25.htm
# Finished scraping 398 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sodexo-USA-EI_IE425.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-GEICO-EI_IE270.11,16.htm
# Finished scraping 406 companies
# Finished scraping 406 companies
# Finished scraping 406 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Stericycle-EI_IE6009.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Avis-Budget-Group-EI_IE7303.11,28.htm
# Finished scraping 412 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Avis-Budget-Group-EI_IE7303.11,28.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Pitney-Bowes-EI_IE535.11,23.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-University-of-Phoenix-EI_IE130372.11,32.htm
# Finished scraping 419 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Stop-and-Shop-EI_IE2117.11,24.htm
# Finished scraping 427 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-J-C-Penney-EI_IE361.11,21.htm
# Finished scraping 436 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Eurofins-Scientific-EI_IE25113.11,30.htm
# Finished scraping 445 companies
# Finished scraping 445 companies
# Finished scraping 455 companies
# Finished scraping 465 companies
# Finished scraping 474 companies
# Finished scraping 474 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Coforge-EI_IE36319.11,18.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sogeti-EI_IE12028.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Sunrise-Senior-Living-EI_IE6023.11,32.htm
# Finished scraping 481 companies
# Finished scraping 491 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Banfield-Pet-Hospital-EI_IE137890.11,32.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-ExxonMobil-EI_IE237.11,21.htm
# Finished scraping 499 companies
# Finished scraping 509 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-DISH-EI_IE4501.11,15.htm
# Finished scraping 518 companies
# Finished scraping 518 companies
# Finished scraping 528 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Alorica-EI_IE17814.11,18.htm
# Finished scraping 537 companies
# Finished scraping 547 companies
# Finished scraping 557 companies
# Finished scraping 557 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm
# Finished scraping 563 companies
# Finished scraping 572 companies
# Finished scraping 572 companies
# Finished scraping 581 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Mercury-Systems-EI_IE4049.11,26.htm
# Finished scraping 589 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-CMG-Financial-EI_IE719461.11,24.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Atlassian-EI_IE115699.11,20.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Milwaukee-Tool-EI_IE13627.11,25.htm
# Finished scraping 595 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-RingCentral-EI_IE197577.11,22.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Ryan-LLC-EI_IE26296.11,19.htm
# Finished scraping 603 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Nugget-Market-EI_IE148409.11,24.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Power-Design-EI_IE324670.11,23.htm
# Finished scraping 611 companies
# Finished scraping 611 companies
# Finished scraping 611 companies
# Finished scraping 621 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-GitLab-EI_IE1296544.11,17.htm
# Finished scraping 630 companies
# Finished scraping 639 companies
# Finished scraping 639 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Talend-EI_IE330195.11,17.htm
# Finished scraping 647 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Alarm-com-EI_IE268820.11,20.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Avantive-Solutions-EI_IE367452.11,29.htm
# Finished scraping 654 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Avantive-Solutions-EI_IE367452.11,29.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Alarm-com-EI_IE268820.11,20.htm
# Finished scraping 661 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-the-LEGO-Group-EI_IE3944.11,25.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Full-Sail-University-EI_IE117893.11,31.htm
# Finished scraping 669 companies
# Finished scraping 669 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Daugherty-Business-Solutions-EI_IE233317.11,39.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Medidata-Solutions-EI_IE16679.11,29.htm
# Finished scraping 674 companies
# Finished scraping 684 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-ABC-Supply-Co-EI_IE657069.11,24.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Ping-Identity-EI_IE380907.11,24.htm
# Finished scraping 690 companies
# Finished scraping 690 companies
# Finished scraping 699 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Guidewire-EI_IE122537.11,20.htm
# Finished scraping 705 companies
# Finished scraping 713 companies
# Finished scraping 713 companies
# Finished scraping 720 companies
# Finished scraping 730 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-PrideStaff-EI_IE27841.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Blattner-Energy-EI_IE375978.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-IFC-EI_IE18874.11,14.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Gallup-EI_IE7246.11,17.htm
# Finished scraping 736 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Freedom-Mortgage-EI_IE346796.11,27.htm
# Finished scraping 744 companies
# Finished scraping 744 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Trilogy-Health-Services-EI_IE212879.11,34.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-PSCU-EI_IE18949.11,15.htm
# Finished scraping 751 companies
# Finished scraping 761 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Dominium-EI_IE153831.11,19.htm
# Finished scraping 769 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Youfit-EI_IE464381.11,17.htm
# Finished scraping 778 companies
# Finished scraping 788 companies
# Finished scraping 797 companies
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-86-3417edd4fc11> in <module>()
# ----> 1 scraping_pages(130)
#
# <ipython-input-85-d10640a51969> in scraping_pages(num_pages)
#      17         company_links = []
#      18         for elem in elems:
# ---> 19             company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
#      20             if 'Overview' in company_link:
#      21                 company_links.append(company_link) #each company's 'Overview' link added to company_link list
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in get_attribute(self, name)
#     139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
# --> 141                 self, name)
#     142         else:
#     143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=88.0.4324.146)

# %%
print(len(companies5))
print("unsuccessful: ", len(unsuccessful_links5))
unsuccessful_links5
# Out:
# 797
# unsuccessful:  108
# ['https://www.glassdoor.com/Overview/Working-at-Texas-Instruments-EI_IE651.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Nokia-EI_IE3494.11,16.htm',
#  'https://www.glassdoor.com/Overview/Working-at-
# 1           Burbank, CA  Motion Picture Production & Distribution
# 2       Santa Clara, CA   Enterprise Software & Network Solutions
# 3    Universal City, CA  Motion Picture Production & Distribution
# 4       Dublin, Ireland            Financial Analytics & Research
# ..                  ...                                       ...
# 792    Fort Collins, CO                   Colleges & Universities
# 793         Concord, CA                    Staffing & Outsourcing
# 794           Miami, FL          Health Care Services & Hospitals
# 795      Scottsdale, AZ   Enterprise Software & Network Solutions
# 796      San Marcos, TX                   Colleges & Universities
#
#     RATING_OVERALL RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB  \
# 0              4.1       4.0       4.2       3.9       3.8       3.9
# 1              4.1       4.3       4.2       3.6       3.5       3.9
# 2              4.1       4.4       4.1       3.8       3.9       4.2
# 3              4.1       4.4       4.0       3.7       3.4       4.0
# 4              4.1       4.3       4.2       3.9       3.8       4.0
# ..             ...       ...       ...       ...       ...       ...
# 792            4.3       3.4       4.0       4.0       3.7       3.3
# 793            4.3       3.9       4.4       4.4       4.2       4.1
# 794            4.3       4.5       3.9       3.7       3.5       4.3
# 795            4.3       4.2       4.4       4.1       4.0       4.0
# 796            4.3       4.5       4.3       4.2       4.0       3.4
#
#     RATING_CO            NUM_REVIEWS  \
# 0         3.8    See All 950 Reviews
# 1         3.7  See All 7,415 Reviews
# 2         3.9  See All 1,322 Reviews
# 3         3.7  See All 1,163 Reviews
# 4         3.8  See All 3,427 Reviews
# ..        ...                    ...
# 792       3.7  See All 1,016 Reviews
# 793       4.2    See All 163 Reviews
# 794       3.9    See All 155 Reviews
# 795       4.1  See All 1,855 Reviews
# 796       3.9    See All 710 Reviews
#
#                                            DESCRIPTION  \
# 0    Huron is a global consultancy that helps our c...
# 1    The monarch of this magic kingdom is no man bu...
# 2    At ServiceNow, we make the world of work, work...
# 3    Movies and theme parks are the center of Unive...
# 4    Experian is the leading global information ser...
# ..                                                 ...
# 792  Colorado State University (CSU) got its start ...
# 793  The Ascent Services Group (Ascent) is an Ameri...
# 794  Jackson Health System, an integrated healthcar...
# 795  Blue Yonder is the world leader in digital sup...
# 796  Texas State University-San Marcos is saddled u...
#
#                                                MISSION
# 0                                                  N/A
# 1                                                  N/A
# 2                                                  N/A
# 3                                                  N/A
# 4    Mission: We help to give our customers the pow...
# ..                                                 ...
# 792                                                N/A
# 793                                                N/A
# 794                                                N/A
# 795  Mission: Our mission is to empower every perso...
# 796                                                N/A
#
# [797 rows x 14 columns]

# %%
df_csv5 = df5_797.to_csv('glassdoor_ratings5_797.csv', index=False) ###########################################

# %% [markdown]
# #### Attept 3:

# %%
##3rd try

unsuccessful_links3 = []
companies3 = []

def scraping_pages(num_pages):
    #Creating 'n' urls with url_roots to scrape
    url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
    nums = [x+11 for x in range(num_pages)] 
    url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root
    
    for u in url_mains:
        driver.get(u)
            
    #looking for 'Overview' links from each main search page
        elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
        company_links = []
        for elem in elems:
            company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
            if 'Overview' in company_link:
                company_links.append(company_link) #each company's 'Overview' link added to company_link list  

        for url in company_links:
            try: #fail safe for inevitable errors
                driver.get(url)
                time.sleep(1)

##---------------------------------------- Handling login ------------------------------------------##
                name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
                pw = 'pw'
                
                try: #login                    
                    username = driver.find_element_by_id("userEmail")
                    password = driver.find_element_by_id("userPassword")
                    submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
                    username.send_keys(name)
                    password.send_keys(pw)
                    submit.click()
                    time.sleep(3) #lettin page load
                except: #no login required
                    pass

##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
                time.sleep(4)
                name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
                size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
                headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
                industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
                try:
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
                except: 
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

            #Gather Description - handling "Read More" button
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
                    read_more.click()
                    time.sleep(1)
                    description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
                except:
                    description = "N/A"

            #Gather Mission - handling "Read More" button    
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
                    read_more.click()
                    time.sleep(1)
                    mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
                except:
                    mission = "N/A"

##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
            #Webpage layout 1
                try: 
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
                    time.sleep(5) #let page load

                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
            #Webpage layout 2
                except: 
                    driver.get(url) #recalling url
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
                    time.sleep(5) #let page load
                    
                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
##---------------------------------------- Creating a Dictionary ----------------------------------------##
                companies3.append({
                    "NAME" : name,
                    "SIZE" : size,
                    "LOCATION_HQ" : headquarters,
                    "INDUSTRY" : industry,
                    "RATING_OVERALL" : rating_overall,
                    "RATING_DI" : rating_DI,
                    "RATING_CV" : rating_CV,
                    "RATING_WL" : rating_WL,
                    "RATING_SM" : rating_SM,
                    "RATING_CB" : rating_CB,
                    "RATING_CO" : rating_CO,
                    "NUM_REVIEWS" : num_reviews,
                    "DESCRIPTION" : description,
                    "MISSION" : mission
                                 })

            except: #fail safe for inevitable errors
                unsuccessful_links3.append(url) #adding unsuccessful urls to a list
                print('ERROR: ', url)
                time.sleep(10)
                
        print(f'Finished scraping {len(companies3)} companies')
        df = pd.DataFrame(companies)
    return df

# %%
scraping_pages(140)
# Out:
# Finished scraping 10 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Stryker-EI_IE1918.11,18.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-University-of-Southern-California-EI_IE3027.11,44.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Penn-State-EI_IE2931.11,21.htm
# Finished scraping 17 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Boston-Scientific-EI_IE2187.11,28.htm
# Finished scraping 25 companies
# Finished scraping 35 companies
# Finished scraping 45 companies
# Finished scraping 45 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-AstraZeneca-EI_IE9214.11,22.htm
# Finished scraping 54 companies
# Finished scraping 54 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Houston-Methodist-EI_IE4460.11,28.htm
# Finished scraping 61 companies
# Finished scraping 71 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Nokia-EI_IE3494.11,16.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Schneider-Electric-EI_IE3956.11,29.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Texas-Instruments-EI_IE651.11,28.htm
# Finished scraping 78 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Memorial-Sloan-Kettering-EI_IE4711.11,35.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-NYU-Langone-Health-EI_IE121521.11,29.htm
# Finished scraping 85 companies
# Finished scraping 85 companies
# Finished scraping 85 companies
# Finished scraping 85 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Synopsys-EI_IE2143.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Lockheed-Martin-EI_IE404.11,26.htm
# Finished scraping 93 companies
# Finished scraping 93 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-T-Mobile-EI_IE9302.11,19.htm
# Finished scraping 101 companies
# Finished scraping 101 companies
# Finished scraping 101 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Kimberly-Clark-EI_IE383.11,25.htm
# Finished scraping 110 companies
# Finished scraping 110 companies
# Finished scraping 110 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Express-Employment-Professionals-EI_IE11188.11,43.htm
# Finished scraping 119 companies
# Finished scraping 119 companies
# Finished scraping 119 companies
# Finished scraping 129 companies
# Finished scraping 129 companies
# Finished scraping 139 companies
# Finished scraping 149 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Leidos-EI_IE730545.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Coach-EI_IE12070.11,16.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Perficient-EI_IE9329.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Charles-Schwab-EI_IE144.11,25.htm
# Finished scraping 155 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cellular-Sales-EI_IE152005.11,25.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Leidos-EI_IE730545.11,17.htm
# Finished scraping 163 companies
# Finished scraping 173 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Prudential-EI_IE2944.11,21.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Kellogg-Company-EI_IE377.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-General-Dynamics-Mission-Systems-EI_IE941740.11,43.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-BASF-EI_IE4231.11,15.htm
# Finished scraping 179 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-BASF-EI_IE4231.11,15.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cushman-and-Wakefield-EI_IE7416.11,32.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Pratt-and-Whitney-EI_IE11041.11,28.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Gap-EI_IE114118.11,14.htm
# Finished scraping 185 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-The-Cheesecake-Factory-EI_IE2229.11,33.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Esri-EI_IE4043.11,15.htm
# Finished scraping 192 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Vanderbilt-University-Medical-Center-EI_IE34889.11,47.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-IQVIA-EI_IE8347.11,16.htm
# Finished scraping 199 companies
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-59-b2f3f57905e1> in <module>()
# ----> 1 scraping_pages(140)
#
# <ipython-input-58-83047a672975> in scraping_pages(num_pages)
#      17         company_links = []
#      18         for elem in elems:
# ---> 19             company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
#      20             if 'Overview' in company_link:
#      21                 company_links.append(company_link) #each company's 'Overview' link added to company_link list
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in get_attribute(self, name)
#     139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
# --> 141                 self, name)
#     142         else:
#     143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=88.0.4324.146)

# %%
print(len(companies3))
print('unsuccessful: ', len(unsuccessful_links3))

unsuccessful_links3
# Out:
# 199
# unsuccessful:  35
# ['https://www.glassdoor.com/Overview/Working-at-Stryker-EI_IE1918.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-University-of-Southern-California-EI_IE3027.11,44.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Penn-State-EI_IE2931.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Boston-Scientific-EI_IE2187.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-AstraZeneca-EI_IE9214.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Houston-Methodist-EI_IE4460.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Nokia-EI_IE3494.11,16.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Schneider-Electric-EI_IE3956.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Texas-Instruments-EI_IE651.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Memorial-Sloan-Kettering-EI_IE4711.11,35.htm',
#  'https://www.glassdoor.com/Overview/Working-at-NYU-Langone-Health-EI_IE121521.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Synopsys-EI_IE2143.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Lockheed-Martin-EI_IE404.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-T-Mobile-EI_IE9302.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Kimberly-Clark-EI_IE383.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Express-Employment-Professionals-EI_IE11188.11,43.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Leidos-EI_IE730545.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Coach-EI_IE12070.11,16.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Perficient-EI_IE9329.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Charles-Schwab-EI_IE144.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cellular-Sales-EI_IE152005.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Leidos-EI_IE730545.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Prudential-EI_IE2944.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Kellogg-Company-EI_IE377.11,26.htm',
#  'https://www.glassdoor.com/Overview/Working-at-General-Dynamics-Mission-Systems-EI_IE941740.11,43.htm',
#  'https://www.glassdoor.com/Overview/Working-at-BASF-EI_IE4231.11,15.htm',
#  'https://www.glassdoor.com/Overview/Working-at-BASF-EI_IE4231.11,15.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cushman-and-Wakefield-EI_IE7416.11,32.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Pratt-and-Whitney-EI_IE11041.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Gap-EI_IE114118.11,14.htm',
#  'https://www.glassdoor.com/Overview/Working-at-The-Cheesecake-Factory-EI_IE2229.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Esri-EI_IE4043.11,15.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Vanderbilt-University-Medical-Center-EI_IE34889.11,47.htm',
#  'https://www.glassdoor.com/Overview/Working-at-IQVIA-EI_IE8347.11,16.htm']

# %%
df3_199 = pd.DataFrame(companies)
df3_199
# Out:
#                                                 NAME                     SIZE  \
# 0                                             Google         10000+ Employees
# 1                                          Microsoft         10000+ Employees
# 2                                              Apple         10000+ Employees
# 3                                       US Air Force         10000+ Employees
# 4                                      Cisco Systems         10000+ Employees
# 5                                        Capital One         10000+ Employees
# 6                                           Qualcomm         10000+ Employees
# 7                                  Intel Corporation         10000+ Employees
# 8                                    Bank of America         10000+ Employees
# 9                                          Accenture         10000+ Employees
# 10                          Florida State University         10000+ Employees
# 11                                         Paylocity   1001 to 5000 Employees
# 12                                    US Coast Guard         10000+ Employees
# 13                            University of Virginia         10000+ Employees
# 14                                 Boston University         10000+ Employees
# 15                             Texas Tech University                  Unknown
# 16                         University of Connecticut   1001 to 5000 Employees
# 17                                   Mastech Digital   1001 to 5000 Employees
# 18                                          Facebook         10000+ Employees
# 19                            University of Maryland         10000+ Employees
# 20                            University of Maryland         10000+ Employees
# 21                           Boston Consulting Group         10000+ Employees
# 22                             Royal Caribbean Group         10000+ Employees
# 23                                            Akamai  5001 to 10000 Employees
# 24                          Arizona State University  5001 to 10000 Employees
# 25  Washington University in St. Louis\nHiring Surge         10000+ Employees
# 26                                   Yale University         10000+ Employees
# 21   See All 3,766 Reviews  Boston Consulting Group partners with leaders ...
# 22   See All 1,587 Reviews  Royal Caribbean Group (NYSE: RCL) is a cruise ...
# 23   See All 1,761 Reviews  Akamai is your competitive edge for digital tr...
# 24   See All 2,814 Reviews  Sun lovers and knowledge seekers can turn to A...
# 25   See All 1,644 Reviews  Washington University in St. Louis is the gate...
# 26   See All 1,521 Reviews  What do former President George W. Bush and ac...
# 27   See All 2,525 Reviews  The University of Pennsylvania was founded by ...
# 28   See All 3,029 Reviews                                                N/A
# 29   See All 2,067 Reviews  The Georgia Institute of Technology, commonly ...
# 30   See All 2,002 Reviews  If you want to grow grapes and make wine in Na...
# 31   See All 2,975 Reviews  Higher education is at the core of this Big Ap...
# 32   See All 3,106 Reviews  Texas A&M opened its doors in 1876 as the stat...
# 33   See All 1,915 Reviews  Since its founding in 1848, this campus has be...
# 34   See All 1,991 Reviews  Made-to-order hamburgers are in and franchisin...
# 35   See All 1,785 Reviews  Duke University is home to nearly 15,000 Blue ...
# 36   See All 3,184 Reviews  Stanford is one of the world's leading researc...
#
#                                               MISSION
# 0                                                 N/A
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4   Mission: Cisco wants you to bring your uniquen...
# 5   Mission: Capital One is an equal opportunity e...
# 6                                                 N/A
# 7                                                 N/A
# 8                                                 N/A
# 9                                                 N/A
# 10                                                N/A
# 11  Mission: Paylocity offers an intuitive, easy-t...
# 12                                                N/A
# 13                                                N/A
# 14  Mission: Boston University is an international...
# 15                                                N/A
# 16                                                N/A
# 17                                                N/A
# 18                                                N/A
# 19                                                N/A
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23                                                N/A
# 24  Mission: ASU is a comprehensive public researc...
# 25                                                N/A
# 26                                                N/A
# 27                                                N/A
# 28                                                N/A
# 29                                                N/A
# 30                                                N/A
# 31                                                N/A
# 32  Mission: Texas A&M University is dedicated to ...
# 33  Mission: The University of Wisconsin–Madison i...
# 34                                                N/A
# 35                                                N/A
# 36  Mission: Stanford University's Founding Grant ...

# %%
df_csv3 = df3_199.to_csv('glassdoor_ratings3_199.csv', index=False)

# %% [markdown]
# #### Attempt 2:

# %%
##2nd try

unsuccessful_links = []
companies = []

def scraping_pages(num_pages):
    #Creating 'n' urls with url_roots to scrape
    url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
    nums = [x+7 for x in range(num_pages)] 
    url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root
    
    for u in url_mains:
        driver.get(u)
            
    #looking for 'Overview' links from each main search page
        elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
        company_links = []
        for elem in elems:
            company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
            if 'Overview' in company_link:
                company_links.append(company_link) #each company's 'Overview' link added to company_link list  

        for url in company_links:
            try: #fail safe for inevitable errors
                driver.get(url)
                time.sleep(1)

##---------------------------------------- Handling login ------------------------------------------##
                name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
                pw = 'pw'
                
                try: #login                    
                    username = driver.find_element_by_id("userEmail")
                    password = driver.find_element_by_id("userPassword")
                    submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
                    username.send_keys(name)
                    password.send_keys(pw)
                    submit.click()
                    time.sleep(3) #lettin page load
                except: #no login required
                    pass

##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
                time.sleep(4)
                name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
                size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
                headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
                industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
                try:
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
                except: 
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

            #Gather Description - handling "Read More" button
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
                    read_more.click()
                    time.sleep(1)
                    description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
                except:
                    description = "N/A"

            #Gather Mission - handling "Read More" button    
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
                    read_more.click()
                    time.sleep(1)
                    mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
                except:
                    mission = "N/A"

##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
            #Webpage layout 1
                try: 
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
                    time.sleep(5) #let page load

                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
            #Webpage layout 2
                except: 
                    driver.get(url) #recalling url
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
                    time.sleep(5) #let page load
                    
                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
##---------------------------------------- Creating a Dictionary ----------------------------------------##
                companies.append({
                    "NAME" : name,
                    "SIZE" : size,
                    "LOCATION_HQ" : headquarters,
                    "INDUSTRY" : industry,
                    "RATING_OVERALL" : rating_overall,
                    "RATING_DI" : rating_DI,
                    "RATING_CV" : rating_CV,
                    "RATING_WL" : rating_WL,
                    "RATING_SM" : rating_SM,
                    "RATING_CB" : rating_CB,
                    "RATING_CO" : rating_CO,
                    "NUM_REVIEWS" : num_reviews,
                    "DESCRIPTION" : description,
                    "MISSION" : mission
                                 })

            except: #fail safe for inevitable errors
                unsuccessful_links.append(url) #adding unsuccessful urls to a list
                print('ERROR: ', url)
                time.sleep(10)
                
        print(f'Finished scraping {len(companies)} companies')
        df = pd.DataFrame(companies)
    return df

# %%
scraping_pages(140)
# Out:
# Finished scraping 10 companies
# Finished scraping 20 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Paycom-EI_IE136736.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Intuit-EI_IE2293.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-H-E-B-EI_IE2824.11,16.htm
# Finished scraping 27 companies
# Finished scraping 37 companies
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-45-b2f3f57905e1> in <module>()
# ----> 1 scraping_pages(140)
#
# <ipython-input-44-710299f4eeff> in scraping_pages(num_pages)
#      17         company_links = []
#      18         for elem in elems:
# ---> 19             company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
#      20             if 'Overview' in company_link:
#      21                 company_links.append(company_link) #each company's 'Overview' link added to company_link list
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in get_attribute(self, name)
#     139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
# --> 141                 self, name)
#     142         else:
#     143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=88.0.4324.146)

# %%
len(companies)
# Out:
# 37

# %%
print(len(companies))
unsuccessful_links
# Out:
# 37
# ['https://www.glassdoor.com/Overview/Working-at-Paycom-EI_IE136736.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Intuit-EI_IE2293.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-H-E-B-EI_IE2824.11,16.htm']

# %%
df2_37 = pd.DataFrame(companies)
df2_37
# Out:
#                                                 NAME                     SIZE  \
# 0                                             Google         10000+ Employees
# 1                                          Microsoft         10000+ Employees
# 2                                              Apple         10000+ Employees
# 3                                       US Air Force         10000+ Employees
# 4                                      Cisco Systems         10000+ Employees
# 5                                        Capital One         10000+ Employees
# 6                                           Qualcomm         10000+ Employees
# 7                                  Intel Corporation         10000+ Employees
# 8                                    Bank of America         10000+ Employees
# 9                                          Accenture         10000+ Employees
# 10                          Florida State University         10000+ Employees
# 11                                         Paylocity   1001 to 5000 Employees
# 12                                    US Coast Guard         10000+ Employees
# 13                            University of Virginia         10000+ Employees
# 14                                 Boston University         10000+ Employees
# 15                             Texas Tech University                  Unknown
# 16                         University of Connecticut   1001 to 5000 Employees
# 17                                   Mastech Digital   1001 to 5000 Employees
# 18                                          Facebook         10000+ Employees
# 19                            University of Maryland         10000+ Employees
# 20                            University of Maryland         10000+ Employees
# 21                           Boston Consulting Group         10000+ Employees
# 22                             Royal Caribbean Group         10000+ Employees
# 23                                            Akamai  5001 to 10000 Employees
# 24                          Arizona State University  5001 to 10000 Employees
# 25  Washington University in St. Louis\nHiring Surge         10000+ Employees
# 26                                   Yale University         10000+ Employees
# 27                        University of Pennsylvania         10000+ Employees
# 28                                         lululemon         10000+ Employees
# 29                                      Georgia Tech  5001 to 10000 Employees
# 30                                          UC Davis         10000+ Employees
# 31                         NYU (New York University)         10000+ Employees
# 32                Texas A&M University\nHiring Surge         10000+ Employees
# 33                   University of Wisconsin-Madison         10000+ Employees
# 34                                   In-N-Out Burger         10000+ Employees
# 35                                   Duke University         10000+ Employees
# 36                               Stanford University         10000+ Employees
#
#              LOCATION_HQ                                 INDUSTRY  \
# 0      Mountain View, CA                                 Internet
# 1            Redmond, WA             Computer Hardware & Software
# 2          Cupertino, CA             Computer Hardware & Software
# 3         Washington, DC                         Federal Agencies
# 4           San Jose, CA             Computer Hardware & Software
# 5            Mc Lean, VA                    Banks & Credit Unions
# 6          San Diego, CA             Computer Hardware & Software
# 7        Santa Clara, CA             Computer Hardware & Software
# 8          Charlotte, NC                    Banks & Credit Unions
# 9        Dublin, Ireland                               Consulting
# 10       Tallahassee, FL                  Colleges & Universities
# 11        Schaumburg, IL  Enterprise Software & Network Solutions
# 12        Washington, DC                         Federal Agencies
# 13   Charlottesville, VA                  Colleges & Universities
# 14            Boston, MA                  Colleges & Universities
# 15           Lubbock, TX                  Colleges & Universities
# 16  Storrs Mansfield, CT                  Colleges & Universities
# 6                                                 N/A
# 7                                                 N/A
# 8                                                 N/A
# 9                                                 N/A
# 10                                                N/A
# 11  Mission: Paylocity offers an intuitive, easy-t...
# 12                                                N/A
# 13                                                N/A
# 14  Mission: Boston University is an international...
# 15                                                N/A
# 16                                                N/A
# 17                                                N/A
# 18                                                N/A
# 19                                                N/A
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23                                                N/A
# 24  Mission: ASU is a comprehensive public researc...
# 25                                                N/A
# 26                                                N/A
# 27                                                N/A
# 28                                                N/A
# 29                                                N/A
# 30                                                N/A
# 31                                                N/A
# 32  Mission: Texas A&M University is dedicated to ...
# 33  Mission: The University of Wisconsin–Madison i...
# 34                                                N/A
# 35                                                N/A
# 36  Mission: Stanford University's Founding Grant ...

# %%
df_csv2 = df2_37.to_csv('glassdoor_ratings2_37.csv', index=False)

# %% [markdown]
# #### Attept 1:

# %%
df1_62 = pd.DataFrame(companies)
df1_62
# Out:
#                              NAME                     SIZE  \
# 0                          Google         10000+ Employees
# 1                       Microsoft         10000+ Employees
# 2                           Apple         10000+ Employees
# 3                    US Air Force         10000+ Employees
# 4                   Cisco Systems         10000+ Employees
# ..                            ...                      ...
# 57  NewYork-Presbyterian Hospital         10000+ Employees
# 58                          Bayer         10000+ Employees
# 59                        Netflix  5001 to 10000 Employees
# 60                  Goldman Sachs         10000+ Employees
# 61                        HP Inc.         10000+ Employees
#
#             LOCATION_HQ                               INDUSTRY RATING_OVERALL  \
# 0     Mountain View, CA                               Internet            4.5
# 1           Redmond, WA           Computer Hardware & Software            4.4
# 2         Cupertino, CA           Computer Hardware & Software            4.3
# 3        Washington, DC                       Federal Agencies            4.2
# 4          San Jose, CA           Computer Hardware & Software            4.2
# ..                  ...                                    ...            ...
# 57         New York, NY       Health Care Services & Hospitals            4.2
# 58  Leverkusen, Germany              Biotech & Pharmaceuticals            4.1
# 59        Los Gatos, CA                               Internet            4.1
# 60         New York, NY  Investment Banking & Asset Management            4.1
# 61        Palo Alto, CA           Computer Hardware & Software            4.1
#
#    RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB RATING_CO  \
# 0        4.4       4.4       4.3       4.1       4.5       4.3
# 1        4.4       4.3       4.1       4.0       4.1       4.1
# 2        4.4       4.3       3.7       3.7       4.3       3.8
# 3        4.2       4.0       3.3       3.4       4.3       4.2
# 4        4.3       4.3       4.2       3.8       4.1       3.9
# ..       ...       ...       ...       ...       ...       ...
# 57       4.3       4.2       4.0       3.8       4.4       4.2
# 58       4.1       4.0       4.1       3.5       4.2       3.6
# 59       4.2       3.9       3.4       3.6       4.4       3.7
# 60       4.1       3.9       3.0       3.7       4.0       4.1
# 61       4.4       4.3       4.1       3.7       3.7       3.7
#
#                NUM_REVIEWS                                        DESCRIPTION  \
# 0   See All 18,362 Reviews                                                N/A
# 1   See All 29,389 Reviews  Our drive to change the world unites us!\n\nMi...
# 2   See All 20,851 Reviews  We’re a diverse collective of thinkers and doe...
# 3   See All 16,600 Reviews  The mission of the US Department of the Air Fo...
# 4   See All 21,804 Reviews  #WeAreCisco, where each person is unique, but ...
# ..                     ...                                                ...
# 57   See All 1,763 Reviews  At NewYork-Presbyterian, we put patients first...
# 58   See All 4,290 Reviews  Bayer is a global company with a more than 150...
# 59   See All 1,263 Reviews  Netflix is the world's leading streaming enter...
# 60   See All 9,096 Reviews  The Goldman Sachs Group, Inc. is a leading glo...
# 61   See All 4,801 Reviews  From day one, HP broke new ground by refusing ...
#
#                                               MISSION
# 0                                                 N/A
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4   Mission: Cisco wants you to bring your uniquen...
# ..                                                ...
# 57  Mission: NYP is one of the nation’s most compr...
# 58                                                N/A
# 59                                                N/A
# 60                                                N/A
# 61                                                N/A
#
# [62 rows x 14 columns]

# %%
scraping_pages(200)
# Out:
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Google-EI_IE9079.11,17.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Microsoft-EI_IE1651.11,20.htm
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     391         else:
# --> 392             conn.request(method, url, **httplib_request_kw)
#     393
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1253         """Send a complete request to the server."""
# -> 1254         self._send_request(method, url, body, headers, encode_chunked)
#    1255
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             body = _encode(body, 'body')
# -> 1300         self.endheaders(body, encode_chunked=encode_chunked)
#    1301
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1248             raise CannotSendHeader()
# -> 1249         self._send_output(message_body, encode_chunked=encode_chunked)
#    1250
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     186     def connect(self):
# --> 187         conn = self._new_conn()
#     188         self._prepare_conn(conn)
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     171             raise NewConnectionError(
# --> 172                 self, "Failed to establish a new connection: %s" % e
#     173             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fcd1c2f99e8>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-19-ee620cdda0fa> in scraping_pages(num_pages)
#      24             try: #fail safe for inevitable errors
# ---> 25                 driver.get(url)
#      26                 time.sleep(1)
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=50732): Max retries exceeded with url: /session/ec1256482b71fa71fa7fc711540ba60d/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fcd1c2f99e8>: Failed to establish a new connection: [Errno 61] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-ce03c7acfd11> in <module>()
# ----> 1 scraping_pages(200)
#
# <ipython-input-19-ee620cdda0fa> in scraping_pages(num_pages)
#     122                 unsuccessful_links.append(url) #adding unsuccessful urls to a list
#     123                 print('ERROR: ', url)
# --> 124                 time.sleep(10)
#     125
#     126         print(f'Finished scraping {len(companies)} companies')
#
# KeyboardInterrupt:

# %%
driver.close()
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     391         else:
# --> 392             conn.request(method, url, **httplib_request_kw)
#     393
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1253         """Send a complete request to the server."""
# -> 1254         self._send_request(method, url, body, headers, encode_chunked)
#    1255
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             body = _encode(body, 'body')
# -> 1300         self.endheaders(body, encode_chunked=encode_chunked)
#    1301
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1248             raise CannotSendHeader()
# -> 1249         self._send_output(message_body, encode_chunked=encode_chunked)
#    1250
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     186     def connect(self):
# --> 187         conn = self._new_conn()
#     188         self._prepare_conn(conn)
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     171             raise NewConnectionError(
# --> 172                 self, "Failed to establish a new connection: %s" % e
#     173             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f8ea425a908>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-7-2c74144afe2d> in <module>()
# ----> 1 driver.close()
#       2 driver.quit()
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      74         if method in self._encode_url_methods:
#      75             return self.request_encode_url(
# ---> 76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#      78         else:
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     765                 chunked=chunked,
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#     769
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     765                 chunked=chunked,
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#     769
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     765                 chunked=chunked,
#     766                 body_pos=body_pos,
# --> 767                 **response_kw
#     768             )
#     769
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#     729             retries.sleep()
#
# /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     437
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#     441         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=49521): Max retries exceeded with url: /session/63eb3a8cc63b98e6a8fb971171021166/window (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f8ea425a908>: Failed to establish a new connection: [Errno 61] Connection refused',))

# %%
unsuccessful_links
# Out:
# ['https://www.glassdoor.com/Overview/Working-at-Southwest-Airlines-EI_IE611.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-World-Wide-Technology-EI_IE9553.11,32.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Stryker-EI_IE1918.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-University-of-Southern-California-EI_IE3027.11,44.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Penn-State-EI_IE2931.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-REI-EI_IE7319.11,14.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Nokia-EI_IE3494.11,16.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Google-EI_IE9079.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Microsoft-EI_IE1651.11,20.htm']

# %%
len(companies) #62
# Out:
# 62

# %%
df_csv = df.to_csv('glassdoor_ratings1_62.csv', index=False)

# %%
df2_37
# Out:
#                                                 NAME                     SIZE  \
# 0                                             Google         10000+ Employees
# 1                                          Microsoft         10000+ Employees
# 2                                              Apple         10000+ Employees
# 3                                       US Air Force         10000+ Employees
# 4                                      Cisco Systems         10000+ Employees
# 5                                        Capital One         10000+ Employees
# 6                                           Qualcomm         10000+ Employees
# 7                                  Intel Corporation         10000+ Employees
# 8                                    Bank of America         10000+ Employees
# 9                                          Accenture         10000+ Employees
# 10                          Florida State University         10000+ Employees
# 11                                         Paylocity   1001 to 5000 Employees
# 12                                    US Coast Guard         10000+ Employees
# 13                            University of Virginia         10000+ Employees
# 14                                 Boston University         10000+ Employees
# 15                             Texas Tech University                  Unknown
# 16                         University of Connecticut   1001 to 5000 Employees
# 17                                   Mastech Digital   1001 to 5000 Employees
# 15   See All 1,205 Reviews  Texas Tech is steadily building its Raiderland...
# 16   See All 1,096 Reviews  The University of Connecticut (UConn) was foun...
# 17     See All 451 Reviews  Welcome to Mastech Digital. We are an IT Staff...
# 18   See All 6,251 Reviews  Facebook is defined by our unique culture – on...
# 19   See All 2,437 Reviews  Driven by the pursuit of excellence, the Unive...
# 20   See All 2,437 Reviews  Driven by the pursuit of excellence, the Unive...
# 21   See All 3,766 Reviews  Boston Consulting Group partners with leaders ...
# 22   See All 1,587 Reviews  Royal Caribbean Group (NYSE: RCL) is a cruise ...
# 23   See All 1,761 Reviews  Akamai is your competitive edge for digital tr...
# 24   See All 2,814 Reviews  Sun lovers and knowledge seekers can turn to A...
# 25   See All 1,644 Reviews  Washington University in St. Louis is the gate...
# 26   See All 1,521 Reviews  What do former President George W. Bush and ac...
# 27   See All 2,525 Reviews  The University of Pennsylvania was founded by ...
# 28   See All 3,029 Reviews                                                N/A
# 29   See All 2,067 Reviews  The Georgia Institute of Technology, commonly ...
# 30   See All 2,002 Reviews  If you want to grow grapes and make wine in Na...
# 31   See All 2,975 Reviews  Higher education is at the core of this Big Ap...
# 32   See All 3,106 Reviews  Texas A&M opened its doors in 1876 as the stat...
# 33   See All 1,915 Reviews  Since its founding in 1848, this campus has be...
# 34   See All 1,991 Reviews  Made-to-order hamburgers are in and franchisin...
# 35   See All 1,785 Reviews  Duke University is home to nearly 15,000 Blue ...
# 36   See All 3,184 Reviews  Stanford is one of the world's leading researc...
#
#                                               MISSION
# 0                                                 N/A
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4   Mission: Cisco wants you to bring your uniquen...
# 5   Mission: Capital One is an equal opportunity e...
# 6                                                 N/A
# 7                                                 N/A
# 8                                                 N/A
# 9                                                 N/A
# 10                                                N/A
# 11  Mission: Paylocity offers an intuitive, easy-t...
# 12                                                N/A
# 13                                                N/A
# 14  Mission: Boston University is an international...
# 15                                                N/A
# 16                                                N/A
# 17                                                N/A
# 18                                                N/A
# 19                                                N/A
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23                                                N/A
# 24  Mission: ASU is a comprehensive public researc...
# 25                                                N/A
# 26                                                N/A
# 27                                                N/A
# 28                                                N/A
# 29                                                N/A
# 30                                                N/A
# 31                                                N/A
# 32  Mission: Texas A&M University is dedicated to ...
# 33  Mission: The University of Wisconsin–Madison i...
# 34                                                N/A
# 35                                                N/A
# 36  Mission: Stanford University's Founding Grant ...

# %%
##1st try

unsuccessful_links = []
companies = []

def scraping_pages(num_pages):
    #Creating 'n' urls with url_roots to scrape
    url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
    nums = [x+1 for x in range(num_pages)] 
    url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root
    
    for u in url_mains:
        driver.get(u)
            
    #looking for 'Overview' links from each main search page
        elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
        company_links = []
        for elem in elems:
            company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
            if 'Overview' in company_link:
                company_links.append(company_link) #each company's 'Overview' link added to company_link list  

        for url in company_links:
            try: #fail safe for inevitable errors
                driver.get(url)
                time.sleep(1)

##---------------------------------------- Handling login ------------------------------------------##
                name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
                pw = 'pw'
                
                try: #login                    
                    username = driver.find_element_by_id("userEmail")
                    password = driver.find_element_by_id("userPassword")
                    submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
                    username.send_keys(name)
                    password.send_keys(pw)
                    submit.click()
                    time.sleep(3) #lettin page load
                except: #no login required
                    pass

##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
                time.sleep(4)
                name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
                size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
                headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
                industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
                try:
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
                except: 
                    num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

            #Gather Description - handling "Read More" button
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
                    read_more.click()
                    time.sleep(1)
                    description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
                except:
                    description = "N/A"

            #Gather Mission - handling "Read More" button    
                try:
                    read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
                    read_more.click()
                    time.sleep(1)
                    mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
                except:
                    mission = "N/A"

##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
            #Webpage layout 1
                try: 
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
                    time.sleep(5) #let page load

                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
            #Webpage layout 2
                except: 
                    driver.get(url) #recalling url
                    driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
                    time.sleep(5) #let page load
                    
                    rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
                    rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
                    rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
                    rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
                    rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
                    rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
                    rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

                    time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
##---------------------------------------- Creating a Dictionary ----------------------------------------##
                companies.append({
                    "NAME" : name,
                    "SIZE" : size,
                    "LOCATION_HQ" : headquarters,
                    "INDUSTRY" : industry,
                    "RATING_OVERALL" : rating_overall,
                    "RATING_DI" : rating_DI,
                    "RATING_CV" : rating_CV,
                    "RATING_WL" : rating_WL,
                    "RATING_SM" : rating_SM,
                    "RATING_CB" : rating_CB,
                    "RATING_CO" : rating_CO,
                    "NUM_REVIEWS" : num_reviews,
                    "DESCRIPTION" : description,
                    "MISSION" : mission
                                 })

            except: #fail safe for inevitable errors
                unsuccessful_links.append(url) #adding unsuccessful urls to a list
                print('ERROR: ', url)
                time.sleep(10)
                
        print(f'Finished scraping {len(companies)} companies')
        df = pd.DataFrame(companies)
    return df

# %%
len(companies) #62
# Out:
# 62

# %%
df1_62 = pd.DataFrame(companies)
df1_62
# Out:
#                              NAME                     SIZE  \
# 0                          Google         10000+ Employees
# 1                       Microsoft         10000+ Employees
# 2                           Apple         10000+ Employees
# 3                    US Air Force         10000+ Employees
# 4                   Cisco Systems         10000+ Employees
# ..                            ...                      ...
# 57  NewYork-Presbyterian Hospital         10000+ Employees
# 58                          Bayer         10000+ Employees
# 59                        Netflix  5001 to 10000 Employees
# 60                  Goldman Sachs         10000+ Employees
# 61                        HP Inc.         10000+ Employees
#
#             LOCATION_HQ                               INDUSTRY RATING_OVERALL  \
# 0     Mountain View, CA                               Internet            4.5
# 1           Redmond, WA           Computer Hardware & Software            4.4
# 2         Cupertino, CA           Computer Hardware & Software            4.3
# 3        Washington, DC                       Federal Agencies            4.2
# 4          San Jose, CA           Computer Hardware & Software            4.2
# ..                  ...                                    ...            ...
# 57         New York, NY       Health Care Services & Hospitals            4.2
# 58  Leverkusen, Germany              Biotech & Pharmaceuticals            4.1
# 59        Los Gatos, CA                               Internet            4.1
# 60         New York, NY  Investment Banking & Asset Management            4.1
# 61        Palo Alto, CA           Computer Hardware & Software            4.1
#
#    RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB RATING_CO  \
# 0        4.4       4.4       4.3       4.1       4.5       4.3
# 1        4.4       4.3       4.1       4.0       4.1       4.1
# 2        4.4       4.3       3.7       3.7       4.3       3.8
# 3        4.2       4.0       3.3       3.4       4.3       4.2
# 4        4.3       4.3       4.2       3.8       4.1       3.9
# ..       ...       ...       ...       ...       ...       ...
# 57       4.3       4.2       4.0       3.8       4.4       4.2
# 58       4.1       4.0       4.1       3.5       4.2       3.6
# 59       4.2       3.9       3.4       3.6       4.4       3.7
# 60       4.1       3.9       3.0       3.7       4.0       4.1
# 61       4.4       4.3       4.1       3.7       3.7       3.7
#
#                NUM_REVIEWS                                        DESCRIPTION  \
# 0   See All 18,362 Reviews                                                N/A
# 1   See All 29,389 Reviews  Our drive to change the world unites us!\n\nMi...
# 2   See All 20,851 Reviews  We’re a diverse collective of thinkers and doe...
# 3   See All 16,600 Reviews  The mission of the US Department of the Air Fo...
# 4   See All 21,804 Reviews  #WeAreCisco, where each person is unique, but ...
# ..                     ...                                                ...
# 57   See All 1,763 Reviews  At NewYork-Presbyterian, we put patients first...
# 58   See All 4,290 Reviews  Bayer is a global company with a more than 150...
# 59   See All 1,263 Reviews  Netflix is the world's leading streaming enter...
# 60   See All 9,096 Reviews  The Goldman Sachs Group, Inc. is a leading glo...
# 61   See All 4,801 Reviews  From day one, HP broke new ground by refusing ...
#
#                                               MISSION
# 0                                                 N/A
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4   Mission: Cisco wants you to bring your uniquen...
# ..                                                ...
# 57  Mission: NYP is one of the nation’s most compr...
# 58                                                N/A
# 59                                                N/A
# 60                                                N/A
# 61                                                N/A
#
# [62 rows x 14 columns]

# %%
df_csv = df.to_csv('glassdoor_ratings1_62.csv', index=False)

# %%
df1_62
# Out:
#                              NAME                     SIZE  \
# 0                          Google         10000+ Employees
# 1                       Microsoft         10000+ Employees
# 2                           Apple         10000+ Employees
# 3                    US Air Force         10000+ Employees
# 4                   Cisco Systems         10000+ Employees
# ..                            ...                      ...
# 57  NewYork-Presbyterian Hospital         10000+ Employees
# 58                          Bayer         10000+ Employees
# 59                        Netflix  5001 to 10000 Employees
# 60                  Goldman Sachs         10000+ Employees
# 61                        HP Inc.         10000+ Employees
#
#             LOCATION_HQ                               INDUSTRY RATING_OVERALL  \
# 0     Mountain View, CA                               Internet            4.5
# 1           Redmond, WA           Computer Hardware & Software            4.4
# 2         Cupertino, CA           Computer Hardware & Software            4.3
# 3        Washington, DC                       Federal Agencies            4.2
# 4          San Jose, CA           Computer Hardware & Software            4.2
# ..                  ...                                    ...            ...
# 57         New York, NY       Health Care Services & Hospitals            4.2
# 58  Leverkusen, Germany              Biotech & Pharmaceuticals            4.1
# 59        Los Gatos, CA                               Internet            4.1
# 60         New York, NY  Investment Banking & Asset Management            4.1
# 61        Palo Alto, CA           Computer Hardware & Software            4.1
#
#    RATING_DI RATING_CV RATING_WL RATING_SM RATING_CB RATING_CO  \
# 0        4.4       4.4       4.3       4.1       4.5       4.3
# 1        4.4       4.3       4.1       4.0       4.1       4.1
# 2        4.4       4.3       3.7       3.7       4.3       3.8
# 3        4.2       4.0       3.3       3.4       4.3       4.2
# 4        4.3       4.3       4.2       3.8       4.1       3.9
# ..       ...       ...       ...       ...       ...       ...
# 57       4.3       4.2       4.0       3.8       4.4       4.2
# 58       4.1       4.0       4.1       3.5       4.2       3.6
# 59       4.2       3.9       3.4       3.6       4.4       3.7
# 60       4.1       3.9       3.0       3.7       4.0       4.1
# 61       4.4       4.3       4.1       3.7       3.7       3.7
#
#                NUM_REVIEWS                                        DESCRIPTION  \
# 0   See All 18,362 Reviews                                                N/A
# 1   See All 29,389 Reviews  Our drive to change the world unites us!\n\nMi...
# 2   See All 20,851 Reviews  We’re a diverse collective of thinkers and doe...
# 3   See All 16,600 Reviews  The mission of the US Department of the Air Fo...
# 4   See All 21,804 Reviews  #WeAreCisco, where each person is unique, but ...
# ..                     ...                                                ...
# 57   See All 1,763 Reviews  At NewYork-Presbyterian, we put patients first...
# 58   See All 4,290 Reviews  Bayer is a global company with a more than 150...
# 59   See All 1,263 Reviews  Netflix is the world's leading streaming enter...
# 60   See All 9,096 Reviews  The Goldman Sachs Group, Inc. is a leading glo...
# 61   See All 4,801 Reviews  From day one, HP broke new ground by refusing ...
#
#                                               MISSION
# 0                                                 N/A
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4   Mission: Cisco wants you to bring your uniquen...
# ..                                                ...
# 57  Mission: NYP is one of the nation’s most compr...
# 58                                                N/A
# 59                                                N/A
# 60                                                N/A
# 61                                                N/A
#
# [62 rows x 14 columns]

# %% [markdown]
# # Iterative process
# Remaining code below this point is my iterative process in working on the `scraping_pages` function.

# %%
# #2nd try: 2m 46s
# scraping_pages(1)
# Out:
# Finished scraping 10 companies
#               NAME              SIZE        LOCATION_HQ  \
# 0           Google  10000+ Employees  Mountain View, CA
# 1        Microsoft  10000+ Employees        Redmond, WA
# 2                   10000+ Employees      Cupertino, CA
# 3     US Air Force  10000+ Employees     Washington, DC
# 4                   10000+ Employees       San Jose, CA
# 5                   10000+ Employees        Mc Lean, VA
# 6                   10000+ Employees      San Diego, CA
# 7                   10000+ Employees    Santa Clara, CA
# 8  Bank of America  10000+ Employees      Charlotte, NC
# 2  The mission of the US Department of the Air Fo...
# 3  #WeAreCisco, where each person is unique, but ...
# 4  Capital One is where professional achievement ...
# 5  We’re looking for inventive minds to help fuel...
# 6  Intel’s mission is to shape the future of tech...
# 7  Bank of America is one of the world's largest ...
# 8  Accenture is a global professional services co...
#
#                                              MISSION
# 0                                                N/A
# 1                                                N/A
# 2                                                N/A
# 3  Mission: Cisco wants you to bring your uniquen...
# 4  Mission: Capital One is an equal opportunity e...
# 5                                                N/A
# 6                                                N/A
# 7                                                N/A
# 8                                                N/A

# %%
# ##TESTING to create function TESTING to create function  TESTING to create function  TESTING

# def scraping_pages(num_pages):
#     #Creating 'n' urls with url_roots to scrape
#     url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' ## root url
#     nums = [x+1 for x in range(num_pages)] 
#     url_mains = list(map(lambda n: url_root + str(n), nums)) ## add 'n' number to call url page 'n'
    
#     for u in url_mains:
#         driver.get(u)
            
#     #looking for 'Overview' links from each main search page
#         elems = driver.find_elements_by_tag_name('a') ## find links on an individual search page tagged with the 'a' tag
#         company_links = []
#         for elem in elems:
#             company_link = elem.get_attribute('href') ## returns every item with 'href' attribute (links for each company)
#             if 'Overview' in company_link:
#                 company_links.append(company_link) ## each company's 'Overview' link added to list  

#         for url in company_links:
#             try: #fail safe for inevitable errors
#                 driver.get(url)
#                 #source = driver.page_source
#                 #page_source = driver.page_source

# ##---------------------------------------- Handling login ------------------------------------------##
#                 name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
#                 pw = 'pw'
                
#                 try: #login
#                     username = driver.find_element_by_id("userEmail")
#                     password = driver.find_element_by_id("userPassword")
#                     submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#                     username.send_keys(name)
#                     password.send_keys(pw)
#                     submit.click()
#                     time.sleep(3) #lettin page load
#                 except: #no login required
#                     pass

# ##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
#                 name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
#                 size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
#                 headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
#                 industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
#                 try:
#                     num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
#                 except: 
#                     num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

#             #Gather Description - handling "Read More" button
#                 try:
#                     read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
#                     read_more.click()
#                     description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
#                 except:
#                     description = "N/A"

#             #Gather Mission - handling "Read More" button    
#                 try:
#                     read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
#                     read_more.click()
#                     mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
#                 except:
#                     mission = "N/A"

# ##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
#             #Webpage layout 1
#                 try: 
#                     driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#                     time.sleep(5) #let page load

#                     rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#                     rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#                     rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#                     rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#                     rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#                     rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#                     rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

#                     #print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews, description, mission)
#                     time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
#             #Webpage layout 2
#                 except: 
#                     driver.get(url) #recalling url
#                     driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#                     time.sleep(5) #let page load
                    
#                     rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#                     rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#                     rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#                     rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#                     rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#                     rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#                     rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

#                     #print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews, description, mission)
#                     time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
# ##-------------------------------- Creating a Dictionary --------------------------------##
#                 companies.append({
#                     "NAME" : name,
#                     "SIZE" : size,
#                     "LOCATION_HQ" : headquarters,
#                     "INDUSTRY" : industry,
#                     "RATING_OVERALL" : rating_overall,
#                     "RATING_DI" : rating_DI,
#                     "RATING_CV" : rating_CV,
#                     "RATING_WL" : rating_WL,
#                     "RATING_SM" : rating_SM,
#                     "RATING_CB" : rating_CB,
#                     "RATING_CO" : rating_CO,
#                     "NUM_REVIEWS" : num_reviews,
#                     "DESCRIPTION" : description,
#                     "MISSION" : mission
#                                  })

#             except: #fail safe for inevitable errors
#                 unsuccessful_links.append(url) #adding unsuccessful urls to a list
#                 print('ERROR: ', url)
#                 print(unsuccessful_links)
#                 time.sleep(10)
#     return pd.DataFrame(companies)

# %%
# ##USE THIS CODE! - pandas dataframe created

# unsuccessful_links = []
# companies = []

# def scraping_pages(num_pages):
#     #Creating 'n' urls with url_roots to scrape
#     url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=' #root url
#     nums = [x+1 for x in range(num_pages)] 
#     url_mains = list(map(lambda n: url_root + str(n), nums)) #adding 'n' number to call url_root
    
#     for u in url_mains:
#         driver.get(u)
            
#     #looking for 'Overview' links from each main search page
#         elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag
#         company_links = []
#         for elem in elems:
#             company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
#             if 'Overview' in company_link:
#                 company_links.append(company_link) #each company's 'Overview' link added to company_link list  

#         for url in company_links:
#             try: #fail safe for inevitable errors
#                 driver.get(url)

# ##---------------------------------------- Handling login ------------------------------------------##
#                 name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
#                 pw = 'pw'
                
#                 try: #login
#                     username = driver.find_element_by_id("userEmail")
#                     password = driver.find_element_by_id("userPassword")
#                     submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#                     username.send_keys(name)
#                     password.send_keys(pw)
#                     submit.click()
#                     time.sleep(3) #lettin page load
#                 except: #no login required
#                     pass

# ##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
#                 name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
#                 size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
#                 headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
#                 industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
#                 try:
#                     num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
#                 except: 
#                     num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

#             #Gather Description - handling "Read More" button
#                 try:
#                     read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
#                     read_more.click()
#                     description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
#                 except:
#                     description = "N/A"

#             #Gather Mission - handling "Read More" button    
#                 try:
#                     read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
#                     read_more.click()
#                     mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
#                 except:
#                     mission = "N/A"

# ##-------------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
#             #Webpage layout 1
#                 try: 
#                     driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#                     time.sleep(5) #let page load

#                     rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#                     rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#                     rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#                     rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#                     rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#                     rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#                     rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

#                     time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
#             #Webpage layout 2
#                 except: 
#                     driver.get(url) #recalling url
#                     driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#                     time.sleep(5) #let page load
                    
#                     rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#                     rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#                     rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#                     rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#                     rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#                     rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#                     rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

#                     time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                        
# ##---------------------------------------- Creating a Dictionary ----------------------------------------##
#                 companies.append({
#                     "NAME" : name,
#                     "SIZE" : size,
#                     "LOCATION_HQ" : headquarters,
#                     "INDUSTRY" : industry,
#                     "RATING_OVERALL" : rating_overall,
#                     "RATING_DI" : rating_DI,
#                     "RATING_CV" : rating_CV,
#                     "RATING_WL" : rating_WL,
#                     "RATING_SM" : rating_SM,
#                     "RATING_CB" : rating_CB,
#                     "RATING_CO" : rating_CO,
#                     "NUM_REVIEWS" : num_reviews,
#                     "DESCRIPTION" : description,
#                     "MISSION" : mission
#                                  })

#             except: #fail safe for inevitable errors
#                 unsuccessful_links.append(url) #adding unsuccessful urls to a list
#                 print('ERROR: ', url)
#                 time.sleep(10)
#         driver.close()
#         driver.quit()
#     return pd.DataFrame(companies)

# %%
# # THIS CODE WORKS - run through whole page of links
# links = ["https://www.glassdoor.com/Overview/Working-at-Google-EI_IE9079.11,17.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Cisco-Systems-EI_IE1425.11,24.htm"]

# unsuccessful_links = []

# for url in links:
#     try:
#         driver.get(url)
#         source = driver.page_source
#         page_source = driver.page_source

#         name = 'n'
#         pw = 'pw'
    
# ##---------------------------------------- Handling login ------------------------------------------##
#         try: #login
#             username = driver.find_element_by_id("userEmail")
#             password = driver.find_element_by_id("userPassword")
#             submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#             username.send_keys(name)
#             password.send_keys(pw)
#             submit.click()
#             time.sleep(3) #lettin page load
#         except: #no login required
#             pass
        
# ##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
#         name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
#         size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
#         headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
#         industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
#         try:
#             num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
#         except: 
#             num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

#     #Gather Description - handling "Read More" button
#         try:
#             read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
#             read_more.click()
#             description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
#         except:
#             description = "Description: N/A"

#     #Gather Mission - handling "Read More" button    
#         try:
#             read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
#             read_more.click()
#             mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
#         except:
#             mission = "Mission: N/A"

# ##-------------------------------- Gathering Variables - RatingsPop-up --------------------------------##    
#     #webpage layout 1: (Google, Microsoft, Apple, etc)
#         try: 
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#             time.sleep(4) #lettin page load
        
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
    
#             print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews, description, mission)
#             time.sleep(np.random.choice([x/10 for x in range(7,20)])) #some time to rest 
#     #webpage layout 2: (Cisco, Capital One, etc)
#         except: 
#             driver.get(url) #recalling url
        
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#             time.sleep(4) #lettin page load
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
        
#             print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews, description, mission)
#             time.sleep(np.random.choice([x/10 for x in range(7,15)])) #some time to rest 
        
#     except: #fail safe for inevitable errors
#         unsuccessful_links.append(url) #adding unsuccessful urls to a list
#         print('ERROR: ', url)
#         print(unsuccessful_links)
#         time.sleep(10)
# Out:
# Google 10000+ Employees Mountain View, CA Internet 4.5 4.4 4.4 4.3 4.1 4.5 4.3 See All 18,361 Reviews Google is not a conventional company, and we don’t intend to become one. True, we share attributes with the world’s most successful organizations – a focus on innovation and smart business practices comes to mind – but even as we continue to grow, we’re committed to retaining a small-company feel. At Google, we know that every employee has something important to say, and that every employee is integral to our success. We provide individually-tailored compensation packages that can be comprised of competitive salary, bonus, and equity components, along with the opportunity to earn further financial bonuses and rewards.
#
# Googlers thrive in small, focused teams and high-energy environments, believe in the ability of technology to change the world, and are as passionate about their lives as they are about their work. For more information, visit careers.google.com. Mission: N/A
# Microsoft 10000+ Employees Redmond, WA Computer Hardware & Software 4.4 4.4 4.3 4.1 4.0 4.1 4.1 See All 29,389 Reviews Our drive to change the world unites us!
#
# Microsoft is the ideal place for people who have passion for their work and the desire to make an impact—in their careers, in the community and on the world. Microsoft is a unique company; and not just within the tech industry. Here, smart people thrive on their own terms and push their intelligence to its limit. The variety of job opportunities and career advancement at Microsoft is incredible and empowers you to constantly challenge yourself and chart your own course. Mission: N/A
# Apple 10000+ Employees Cupertino, CA Computer Hardware & Software 4.3 4.4 4.3 3.7 3.7 4.3 3.8 See All 20,848 Reviews We’re a diverse collective of thinkers and doers, continually reimagining what’s possible to help us all do what we love in new ways. The people who work here have reinvented entire industries with the Mac, iPhone, iPad, and Apple Watch, as well as with services, including Apple TV, the App Store, Apple Music, and Apple Pay. And the same innovation that goes into our products also applies to our practices — strengthening our commitment to leave the world better than we found it.
#
# Every new product we invent, service we create, or store we open is the result of people working together to make each other’s ideas stronger. That happens here because every one of us strives toward a common goal — creating the best customer experiences. So bring your passion, courage, and original thinking and get ready to share it. This is where your work can make a difference in people’s lives. Including your own. Mission: N/A
# US Air Force 10000+ Employees Washington, DC Federal Agencies 4.2 4.2 4.0 3.3 3.4 4.3 4.2 See All 16,599 Reviews The mission of the US Department of the Air Force is to fly, fight, and win -- in air, space, and cyberspace. Along with the Army, Navy, and Marine Corps, the US Air Force is a major military branch of the US Department of Defense responsible for defending the US and its interests through aerial, space, and cyber warfare. The agency includes more than a dozen major commands, including the Air Force Reserve and Air National Guard. It also consists of field operating agencies and direct reporting units, which are typically assigned to specialized missions. It has more than 150,000 civilian employees and 330,000 active duty personnel, some of whom are deployed in Afghanistan, Iraq, and the Asia/Pacific region. Mission: N/A
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Cisco-Systems-EI_IE1425.11,24.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Capital-One-EI_IE3736.11,22.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Qualcomm-EI_IE640.11,19.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Bank-of-America-EI_IE8874.11,26.htm
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Accenture-EI_IE4138.11,20.htm

# %%
# # THIS CODE WORKS - double check that google's description and mission go through (I think I fixed after running)

# for u in url:
#     try:
#         driver.get(u)
#         source = driver.page_source
#         page_source = driver.page_source

#         name = 'n'
#         pw = 'pw'
    
# ##---------------------------------------- Handling login ------------------------------------------##
#         try: #login required
#             username = driver.find_element_by_id("userEmail")
#             password = driver.find_element_by_id("userPassword")
#             submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#             username.send_keys(name)
#             password.send_keys(pw)
#             submit.click()
#             time.sleep(3) #lettin page load
#         except: #no login required
#             pass
        
# ##---------------------------------- Gathering Variables - Main Page ---------------------------------##                
#         name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
#         size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
#         headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
#         industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
#         try:
#             num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
#         except: 
#             num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

#     #Gather Description - handling "Read More" button
#         try:
#             read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
#             read_more.click()
#             description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
#         except:
#             description = "Description: N/A"

#     #Gather Mission - handling "Read More" button    
#         try:
#             read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
#             read_more.click()
#             mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
#         except:
#             mission = "Mission: N/A"

# ##-------------------------------- Gathering Variables - RatingsPop-up --------------------------------##    
#         try: #webpage layout 1: (Google, Microsoft, Apple, etc)
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#             time.sleep(4) #lettin page load
        
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
    
#             print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews, description, mission)
#             time.sleep(np.random.choice([x/10 for x in range(7,20)])) #some time to rest 
    
#         except: #webpage layout 2: (Cisco, Capital One, etc)
#             driver.get(u) #recalling url
        
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#             time.sleep(4) #lettin page load
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
        
#             print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews, description, mission)
#             time.sleep(np.random.choice([x/10 for x in range(7,15)])) #some time to rest 
        
#     except: #fail safe for inevitable errors
#         print('ERROR: ', u)
#         time.sleep(10)
# Out:
# Google 10000+ Employees Mountain View, CA Internet 4.5 4.4 4.4 4.3 4.1 4.5 4.3 See All 18,359 Reviews Description: N/A Mission: N/A
# Microsoft 10000+ Employees Redmond, WA Computer Hardware & Software 4.4 4.4 4.3 4.1 4.0 4.1 4.1 See All 29,387 Reviews Our drive to change the world unites us!
# Intel Corporation 10000+ Employees Santa Clara, CA Computer Hardware & Software 4.1 4.4 4.1 4.0 3.5 4.0 3.9 See All 17,696 Reviews Intel’s mission is to shape the future of technology to help create a better future for the entire world. By pushing forward in fields like AI, analytics and cloud-to-edge technology, Intel’s work is at the heart of countless innovations. From major breakthroughs like self-driving cars and rebuilding the coral reefs, to things that make everyday life better like blockbuster effects and improved shopping experiences — they’re all powered by Intel technology. With a career at Intel, you have the opportunity to help make the future more wonderful for everyone.
#
# Join us. Mission: N/A
# Orian Engineers 1 to 50 Employees Sunnyvale, CA Computer Hardware & Software 5.0 N/A 4.5 5.0 4.5 5.0 4.5 See All 2 Reviews Description: N/A Mission: N/A
# US Air Force 10000+ Employees Washington, DC Federal Agencies 4.2 4.2 4.0 3.3 3.4 4.3 4.2 See All 16,598 Reviews The mission of the US Department of the Air Force is to fly, fight, and win -- in air, space, and cyberspace. Along with the Army, Navy, and Marine Corps, the US Air Force is a major military branch of the US Department of Defense responsible for defending the US and its interests through aerial, space, and cyber warfare. The agency includes more than a dozen major commands, including the Air Force Reserve and Air National Guard. It also consists of field operating agencies and direct reporting units, which are typically assigned to specialized missions. It has more than 150,000 civilian employees and 330,000 active duty personnel, some of whom are deployed in Afghanistan, Iraq, and the Asia/Pacific region. Mission: N/A

# %%
# ## THIS CODE WORKS - description/mission successful

# for u in url:

#     driver.get(u)
#     source = driver.page_source
#     page_source = driver.page_source
    
#     name = 'n'
#     pw = 'pw'
    
# ##------------------------------------ Handling login ------------------------------------------##
#     try: #login required
#         username = driver.find_element_by_id("userEmail")
#         password = driver.find_element_by_id("userPassword")
#         submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#         username.send_keys(name)
#         password.send_keys(pw)
#         submit.click()
#         time.sleep(1) #lettin page load
#     except: #no login required
#         pass

# ##---------------------------------- Gathering Variables - Main Page ------------------------------------##                

#     name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
    
#     #Gather Description - handling "Read More" button
#     try:
#         read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
#         read_more.click()
#         description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
#     except:
#         description = "Description: N/A"
        
#     #Gather Mission - handling "Read More" button    
#     try:
#         read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
#         read_more.click()
#         mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
#     except:
#         mission = "Mission: N/A"
    
    
# ##---------------------------- Gathering Variables - Ratings pop-up --------------------------------##    
#     try: #webpage layout 1: (Google, Microsoft, Apple, etc)
#         driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#         time.sleep(4) #lettin page load
    
#         rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#         rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#         rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#         rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#         rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#         rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#         rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
    
#         print(name, "\n", description, "\n", mission, "\n")
#         time.sleep(np.random.choice([x/10 for x in range(7,20)])) #some time to rest 
    
#     except: #webpage layout 2: (Cisco, Capital One, etc)
#         driver.get(u) #recalling url
    
#         driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#         time.sleep(4) #lettin page load
#         rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#         rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#         rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#         rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#         rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#         rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#         rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').
#
# Join us.
#  Mission: N/A
#
# Orian Engineers
#  Description: N/A
#  Mission: N/A
#
# US Air Force
#  The mission of the US Department of the Air Force is to fly, fight, and win -- in air, space, and cyberspace. Along with the Army, Navy, and Marine Corps, the US Air Force is a major military branch of the US Department of Defense responsible for defending the US and its interests through aerial, space, and cyber warfare. The agency includes more than a dozen major commands, including the Air Force Reserve and Air National Guard. It also consists of field operating agencies and direct reporting units, which are typically assigned to specialized missions. It has more than 150,000 civilian employees and 330,000 active duty personnel, some of whom are deployed in Afghanistan, Iraq, and the Asia/Pacific region.
#  Mission: N/A

# %%
# # THIS CODE WORKS - all elements except for mission statement and company review

# for u in url:
#     try:
#         driver.get(u)
#         source = driver.page_source
#         page_source = driver.page_source
#         name = 'n'
#         pw = 'pw'
    
# ##---------------------------------------- Handling login ------------------------------------------##
#         try: #login required
#             username = driver.find_element_by_id("userEmail")
#             password = driver.find_element_by_id("userPassword")
#             submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#             username.send_keys(name)
#             password.send_keys(pw)
#             submit.click()
#             time.sleep(1) #lettin page load
#         except: #no login required
#             pass
        
# ##---------------------------------- Gathering Variables ---------------------------------##                
#         name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
#         size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
#         headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
#         industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
#         try:
#             num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
#         except: 
#             num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        


# ##-------------------------------- Handling different page layouts --------------------------------##    
#         try: #webpage layout 1: (Google, Microsoft, Apple, etc)
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#             time.sleep(4) #lettin page load
        
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
    
#             print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews)
#             time.sleep(np.random.choice([x/10 for x in range(7,20)])) #some time to rest 
    
#         except: #webpage layout 2: (Cisco, Capital One, etc)
#             driver.get(u) #recalling url
        
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#             time.sleep(3) #lettin page load
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
        
#             print(name, size, headquarters, industry, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO, num_reviews)
#             time.sleep(np.random.choice([x/10 for x in range(7,15)])) #some time to rest 
        
#     except: #fail safe for inevitable errors
#         print('ERROR: ', u)
#         time.sleep(10)

# %%
# # THIS CODE WORKS

# for u in url:
#     try:
#         driver.get(u)
#         source = driver.page_source
#         page_source = driver.page_source
#         name = 'n'
#         pw = 'pw'
    
# ##------------------------ Handling login --------------------------##
#         try: #login required
#             username = driver.find_element_by_id("userEmail")
#             password = driver.find_element_by_id("userPassword")
#             submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#             username.send_keys(name)
#             password.send_keys(pw)
#             submit.click()
#         except: #no login required
#             pass

# ##---------------- Handling different page layouts ----------------##
    
#         try: #webpage layout 1: (Google, Microsoft, Apple, etc)
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#             time.sleep(4)
        
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
    
#             print(rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO)
#             time.sleep(np.random.choice([x/10 for x in range(7,20)]))
    
#         except: #webpage layout 2: (Cisco, Capital One, etc)
#             driver.get(u) #recalling url
        
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#             time.sleep(3)
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
        
#             print(rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO)
#             time.sleep(np.random.choice([x/10 for x in range(7,15)]))
        
#     except: #fail safe for inevitable errors
#         time.sleep(10)
#         pass

# %%
# url = ["https://www.glassdoor.com/Overview/Working-at-Google-EI_IE9079.11,17.htm"
#           "https://www.glassdoor.com/Overview/Working-at-Microsoft-EI_IE1651.11,20.htm"
# ]

# # WHY DON'T I GET GOOGLE SCRAPE HERE?
# for u in url:
#     try:
#         driver.get(u)
#         source = driver.page_source
#         page_source = driver.page_source
#         name = 'n'
#         pw = 'pw'
        
# ##------------------------ Handling login --------------------------##
#         try: #login required
#             username = driver.find_element_by_id("userEmail")
#             password = driver.find_element_by_id("userPassword")
#             submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#             username.send_keys(name)
#             password.send_keys(pw)
#             submit.click()
#         except: #no login required
#             pass
        
#         name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text

# ##---------------- Handling different page layouts ----------------##
    
#         try: #webpage layout 1: (Google, Microsoft, Apple, etc)
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
#             time.sleep(4)
        
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             try: #failsafe for companies with do DI rating
#                 rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             except:
#                 rating_DI = 'None'
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
    
#             print(name, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO)
#             time.sleep(np.random.choice([x/10 for x in range(7,20)]))
    
#         except: #webpage layout 2: (Cisco, Capital One, etc)
#             driver.get(u) #recalling url
        
#             driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
#             time.sleep(3)
#             rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
#             rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
#             rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
#             rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
#             rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
#             rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
#             rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text
        
#             print(name, rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO)
#             time.sleep(np.random.choice([x/10 for x in range(7,15)]))
        
        
#     except:
#         print('ERROR: ', u)
#         time.sleep(10)
# Out:
# Microsoft 4.4 4.4 4.3 4.1 4.0 4.1 4.1

# %%
# #group 1 code

# # Google
# url = "https://www.glassdoor.com/Overview/Working-at-Microsoft-EI_IE1651.11,20.htm"

# driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
# time.sleep(2)
# rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
# rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
# rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
# rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
# rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
# rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
# rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

# print(rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO)

# %%
# #group 2 code

# # Cisco:
# # url = "https://www.glassdoor.com/Overview/Working-at-Cisco-Systems-EI_IE1425.11,24.htm"
# # Capital One:
# #url = 'https://www.glassdoor.com/Overview/Working-at-Capital-One-EI_IE3736.11,22.htm'

# driver.get(url)

# driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
# time.sleep(3)
# rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
# rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
# rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
# rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
# rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
# rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
# rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
# rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

# time.sleep(np.random.choice([x/10 for x in range(7,15)]))
# print(rating_overall, rating_DI, rating_CV, rating_WL, rating_SM, rating_CB, rating_CO)
# #print(rating_overall)

# %%
# #Testing mission statement
# driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]/span').click()
# time.sleep(2)

# %% [markdown]
# URLs for testing:

# %%
# url = ["https://www.glassdoor.com/Overview/Working-at-Google-EI_IE9079.11,17.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Microsoft-EI_IE1651.11,20.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Cisco-Systems-EI_IE1425.11,24.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Capital-One-EI_IE3736.11,22.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Bank-of-America-EI_IE8874.11,26.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Apple-EI_IE1138.11,16.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Intel-Corporation-EI_IE1519.11,28.htm",
#     "https://www.glassdoor.com/Overview/Working-at-Orian-Engineers-EI_IE608061.11,26.htm",
#     "https://www.glassdoor.com/Overview/Working-at-US-Air-Force-EI_IE41283.11,23.htm"#no DI rating, description, or mission stateme

#       ]

# %%
# # looking for 'Overview' links from each main search page

# # Initiate main links
# elems = driver.find_elements_by_tag_name('a') ## all links located in 'a' tag

# links = []
# for elem in elems:
#     link = elem.get_attribute('href') ## returns every item with 'href' attribute
#     if 'Overview' in link:
#         links.append(link) ## each 'Overview' link added to list

# %%
# # Creating 'n' urls to scrape
# num_pages = 2 #change depending on how many pages you want to scrape

# url_root = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page='
# nums = [x+1 for x in range(num_pages)]

# url_mains = list(map(lambda n: url_root + str(n), nums))
# #url_mains #sanity check
# Out:
# ['https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=1',
#  'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=2']

# %%
# for u in url_mains:
#     driver.get(u)
#     # Initiate main links
#     elems = driver.find_elements_by_tag_name('a') ## all links located in 'a' tag

#     links = []
#     for elem in elems:
#         link = elem.get_attribute('href') ## returns every item with 'href' attribute
#         if 'Overview' in link:
#             links.append(link) ## each 'Overview' link added to list
# # links #sanity check
