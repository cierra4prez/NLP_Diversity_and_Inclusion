# %% [markdown]
# Additional attepts:
# - company size "501 to 1000 Employees"
#     - click the 'next' button instead?
# - try other industries
# - first scrape webpage urls, then run those urls through the scraper
#     - click on company size,
#         - then scrape urls, click next, scrape urls, click next, repeat

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

#from selenium.webdriver import DesiredCapabilities
#from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
#import concurrent.futures

import pandas as pd
import numpy as np
import time

# %% [markdown]
# **DRIVER HERE:**

# %%
#Setting driver and User-Agent to prevent ip block
    
opts = Options()
opts.add_argument("Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36")
#opts.add_argument('headless')

driver = webdriver.Chrome(options=opts)
time.sleep(5)

# %%
#start driver on main url, 
url_main = 'https://www.glassdoor.com/Explore/browse-companies.htm?overall_rating_low=0&page=1&isHiringSurge=0' #main url

driver.get(url_main)
#time.sleep(10)

# %%
#NEXT: #urls_scraped_500to5k =
# urls_scraped_5kto10k = [] 
# urls_scraped_1kto5k = []
#urls_scraped_501to1k = [] #800
#urls_scraped_200to500 = [] #800
#urls_scraped_50to200 = [] #400
#urls_scraped_1to50 = [] #400

# %% [markdown]
# #### grabbing URL's from different company sizes - DUPLICATE THIS
# - 800 urls for 501-1k
# - 800 urls for 201-500
# - urls for 51-200 (400?)
# - urls for 1-50 (400?)

# %%
## click on company size option

# %%
#urls_scraped = []

# %% [markdown]
# # Company size: 501-1k

# %% [markdown]
# **To fetch URL's:**

# %%
#urls_scraped_501to1k = []

# %%
while len(urls_scraped_501to1k) <800: #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE ##
    #scrape page for urls
    elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag

    #list of all links on page
    company_links = [] #all links
    for elem in elems:
        company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
        company_links.append(company_link)
        #iterating through each company's "Overview" url
    for url in company_links:
        if 'Overview' in url:
            urls_scraped_501to1k.append(url) #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE ##

    #click "Next"
    next_button = driver.find_element_by_xpath('//*[@id="ReactCompanyExplorePageContainer"]/div/div/div/div/div[3]/div/ul/li[7]/button')
    next_button.click()
    time.sleep(3)

# %%
print(len(urls_scraped_501to1k))
urls_scraped_501to1k
# Out:
# 802
# ['https://www.glassdoor.com/Overview/Working-at-Vector-Marketing-EI_IE26785.11,27.htm',
#  'https://www.glassdoor.com/Overview/Working-at-AlphaSights-EI_IE465088.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Boys-and-Girls-Clubs-of-America-EI_IE21079.11,42.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Glassdoor-EI_IE100431.11,20.htm',
#  'https://www.glassdoor.com/Overview/Working-at-American-Automobile-Association-AAA-EI_IE2705.11,46.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Planned-Parenthood-EI_IE14417.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Payless-ShoeSource-EI_IE42821.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Party-City-EI_IE6126.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-BCBG-EI_IE8719.11,15.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Middlebury-College-EI_IE21373.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Ultradent-EI_IE253210.11,20.htm',
# ...

# %% [markdown]
# **Run this code after URL's are fetched:**

# %%
urls_scraped_501to1k = ['https://www.glassdoor.com/Overview/Working-at-Vector-Marketing-EI_IE26785.11,27.htm',
 'https://www.glassdoor.com/Overview/Working-at-AlphaSights-EI_IE465088.11,22.htm',
 'https://www.glassdoor.com/Overview/Working-at-Boys-and-Girls-Clubs-of-America-EI_IE21079.11,42.htm',
 'https://www.glassdoor.com/Overview/Working-at-Glassdoor-EI_IE100431.11,20.htm',
 'https://www.glassdoor.com/Overview/Working-at-American-Automobile-Association-AAA-EI_IE2705.11,46.htm',
 'https://www.glassdoor.com/Overview/Working-at-Planned-Parenthood-EI_IE14417.11,29.htm',
 'https://www.glassdoor.com/Overview/Working-at-
11,21.htm',
 'https://www.glassdoor.com/Overview/Working-at-Mercedes-Benz-Research-and-Development-North-America-EI_IE249447.11,63.htm',
 'https://www.glassdoor.com/Overview/Working-at-Everyday-Health-Group-EI_IE101724.11,32.htm',
 'https://www.glassdoor.com/Overview/Working-at-Ibotta-EI_IE922046.11,17.htm',
 'https://www.glassdoor.com/Overview/Working-at-Accela-Inc-EI_IE251072.11,21.htm',
 'https://www.glassdoor.com/Overview/Working-at-Best-Friends-Animal-Society-EI_IE316482.11,38.htm',
 'https://www.glassdoor.com/Overview/Working-at-Cadmus-Group-EI_IE3111.11,23.htm',
 'https://www.glassdoor.com/Overview/Working-at-Campus-Management-Corporation-EI_IE200826.11,40.htm',
 'https://www.glassdoor.com/Overview/Working-at-ClearChoice-Dental-Implant-Centers-EI_IE219623.11,45.htm',
 'https://www.glassdoor.com/Overview/Working-at-Digi-International-EI_IE1646.11,29.htm',
 'https://www.glassdoor.com/Overview/Working-at-Accela-Inc-EI_IE251072.11,21.htm',
 'https://www.glassdoor.com/Overview/Working-at-Best-Friends-Animal-Society-EI_IE316482.11,38.htm',
 'https://www.glassdoor.com/Overview/Working-at-Workrise-EI_IE1036818.11,19.htm',
 'https://www.glassdoor.com/Overview/Working-at-Truckstop-com-EI_IE484559.11,24.htm',
 'https://www.glassdoor.com/Overview/Working-at-NCU-Northcentral-University-EI_IE128722.11,38.htm',
 'https://www.glassdoor.com/Overview/Working-at-Ogilvy-Health-EI_IE34273.11,24.htm',
 'https://www.glassdoor.com/Overview/Working-at-Limelight-Networks-EI_IE42551.11,29.htm',
 'https://www.glassdoor.com/Overview/Working-at-National-Multiple-Sclerosis-Society-EI_IE226661.11,46.htm',
 'https://www.glassdoor.com/Overview/Working-at-Brooks-Running-EI_IE9656.11,25.htm']

# %%
unsuccessful_links_501to1k = [] ####################################################
companies_501to1k = [] #############################################################

#iterating through each company's "Overview" url
for url in urls_scraped_501to1k: ################################################
    try: #fail safe for inevitable errors
        driver.get(url)
        time.sleep(5)

##---------------------------- Gathering Variables - Main Page ---------------------------------##                                
        name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
        size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
        headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
        industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
        try:
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
        except: 
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

    #Gather Description - handling "Read More" button
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
            read_more.click()
            time.sleep(2)
            description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
        except:
            description = "N/A"

    #Gather Mission - handling "Read More" button    
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
            read_more.click()
            time.sleep(2)
            mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
        except:
            mission = "N/A"

##-------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
    #Webpage layout 1
        try: 
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
            time.sleep(5) #let page load

            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
    #Webpage layout 2
        except: 
            driver.get(url) #recalling url
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
            time.sleep(5) #let page load
            
            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                
##---------------------------------- Creating a Dictionary ----------------------------------------##
        companies_501to1k.append({ ####################################################
            "NAME" : name,
            "SIZE" : size,
            "LOCATION_HQ" : headquarters,
            "INDUSTRY" : industry,
            "RATING_OVERALL" : rating_overall,
            "RATING_DI" : rating_DI,
            "RATING_CV" : rating_CV,
            "RATING_WL" : rating_WL,
            "RATING_SM" : rating_SM,
            "RATING_CB" : rating_CB,
            "RATING_CO" : rating_CO,
            "NUM_REVIEWS" : num_reviews,
            "DESCRIPTION" : description,
            "MISSION" : mission
                         })

    except: #fail safe for inevitable errors
        unsuccessful_links_501to1k.append(url) #adding unsuccessful urls to a list ##########
        print('ERROR: ', url)
        time.sleep(10)
    
    print(f'Finished scraping {len(companies_501to1k)} companies') #########################
    #Save dataframe:
    df_501to1k = pd.DataFrame(companies_501to1k) ###############################################
    df_501to1k = df_501to1k.to_csv('data/glassdoor_ratings_501to1k.csv', index=False) ################
print(f'Finished scraping {len(companies_501to1k)} companies') ##############################
# Out:
# Finished scraping 1 companies
# Finished scraping 2 companies
# Finished scraping 3 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Glassdoor-EI_IE100431.11,20.htm
# Finished scraping 3 companies
# Finished scraping 4 companies
# Finished scraping 5 companies
# Finished scraping 6 companies
# Finished scraping 7 companies
# Finished scraping 8 companies
# Finished scraping 9 companies
# Finished scraping 10 companies
# Finished scraping 11 companies
# Finished scraping 12 companies
# Finished scraping 13 companies
# Finished scraping 14 companies
# Finished scraping 15 companies
# Finished scraping 16 companies
# Finished scraping 17 companies
# Finished scraping 18 companies
# Finished scraping 19 companies
# Finished scraping 20 companies
# Finished scraping 21 companies
# Finished scraping 22 companies
# Finished scraping 23 companies
# Finished scraping 24 companies
# Finished scraping 25 companies
# Finished scraping 26 companies
# ...

# %%
print(len(companies_501to1k))
print('unsuccessful: ', len(unsuccessful_links_501to1k))
unsuccessful_links_501to1k
# Out:
# 746
# unsuccessful:  56
# ['https://www.glassdoor.com/Overview/Working-at-Glassdoor-EI_IE100431.11,20.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Sprout-Social-EI_IE701678.11,24.htm',
#  'https://www.glassdoor.com/Overview/Working-at-AppLovin-EI_IE576360.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-CarSense-EI_IE392604.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Pariveda-Solutions-EI_IE105190.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-IMC-Trading-EI_IE278100.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Livongo-Health-EI_IE1175834.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Calix-EI_IE13819.11,16.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Seismic-EI_IE1151159.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Novetta-EI_IE665112.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-C3-ai-EI_IE312703.11,16.htm',
# ...

# %%
pd.read_csv('data/glassdoor_ratings_501to1k.csv')
# Out:
#                                             NAME                   SIZE  \
# 0                               Vector Marketing  501 to 1000 Employees
# 1                                    AlphaSights  501 to 1000 Employees
# 2                  Boys & Girls Clubs of America  501 to 1000 Employees
# 3          American Automobile Association (AAA)  501 to 1000 Employees
# 4                             Planned Parenthood  501 to 1000 Employees
# ..                                           ...                    ...
# 741                                Truckstop.com  501 to 1000 Employees
# 742  NCU (Northcentral University)\nHiring Surge  501 to 1000 Employees
# 743                Ogilvy Health\nPart of Ogilvy  501 to 1000 Employees
# 744                           Limelight Networks  501 to 1000 Employees
# 745                               Brooks Running  501 to 1000 Employees
#
#                 LOCATION_HQ                  INDUSTRY  RATING_OVERALL  \
# ...

# %%
driver.close()
driver.quit()

# %% [markdown]
# # Company size: 201-500

# %% [markdown]
# **To fetch URL's:**

# %%
while len(urls_scraped_201to500<800: #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE ##
    #scrape page for urls
    elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag

    #list of all links on page
    company_links = [] #all links
    for elem in elems:
        company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
        company_links.append(company_link)
        #iterating through each company's "Overview" url
    for url in company_links:
        if 'Overview' in url:
            urls_scraped_201to500.append(url) #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE ##

    #click "Next"
    next_button = driver.find_element_by_xpath('//*[@id="ReactCompanyExplorePageContainer"]/div/div/div/div/div[3]/div/ul/li[7]/button')
    next_button.click()
    time.sleep(3)

# %%
print(len(urls_scraped_201to500))
urls_scraped_201to500

# %% [markdown]
# **Run this code after URL's are fetched:**

# %%
unsuccessful_links_201to500 = [] ####################################################
companies_201to500 = [] #############################################################

#iterating through each company's "Overview" url
for url in urls_scraped_201to500 ################################################
    try: #fail safe for inevitable errors
        driver.get(url)
        time.sleep(5)

##---------------------------- Gathering Variables - Main Page ---------------------------------##                                
        name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
        size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
        headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
        industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
        try:
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
        except: 
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

    #Gather Description - handling "Read More" button
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
            read_more.click()
            time.sleep(2)
            description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
        except:
            description = "N/A"

    #Gather Mission - handling "Read More" button    
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
            read_more.click()
            time.sleep(2)
            mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
        except:
            mission = "N/A"

##-------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
    #Webpage layout 1
        try: 
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
            time.sleep(5) #let page load

            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
    #Webpage layout 2
        except: 
            driver.get(url) #recalling url
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
            time.sleep(5) #let page load
            
            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                
##---------------------------------- Creating a Dictionary ----------------------------------------##
        companies_201to500.append({ ####################################################
            "NAME" : name,
            "SIZE" : size,
            "LOCATION_HQ" : headquarters,
            "INDUSTRY" : industry,
            "RATING_OVERALL" : rating_overall,
            "RATING_DI" : rating_DI,
            "RATING_CV" : rating_CV,
            "RATING_WL" : rating_WL,
            "RATING_SM" : rating_SM,
            "RATING_CB" : rating_CB,
            "RATING_CO" : rating_CO,
            "NUM_REVIEWS" : num_reviews,
            "DESCRIPTION" : description,
            "MISSION" : mission
                         })

    except: #fail safe for inevitable errors
        unsuccessful_links_201to500.append(url) #adding unsuccessful urls to a list ##########
        print('ERROR: ', url)
        time.sleep(10)
    
    print(f'Finished scraping {len(companies_201to500)} companies') #########################
    #Save dataframe:
    df_201to500 = pd.DataFrame(companies_201to500) ###############################################
    df_201to500 = df_201to500.to_csv('data/glassdoor_ratings_201to500.csv', index=False) ################
print(f'Finished scraping {len(companies_201to500)} companies') ##############################
# Out:
# Finished scraping 1 companies

# %%
print(len(companies_201to500))
print('unsuccessful: ', len(unsuccessful_links_201to500))
unsuccessful_links_201to500

# %%
df_201to500

# %%
driver.close()
driver.quit()

# %% [markdown]
# # Company size: 51-200

# %% [markdown]
# **To fetch URL's:**

# %%
#urls_scraped_51to200 = []

# %%
while len(urls_scraped_51to200) < 600: #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE ##
    #scrape page for urls
    elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag

    #list of all links on page
    company_links = [] #all links
    for elem in elems:
        company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
        company_links.append(company_link)
        #iterating through each company's "Overview" url
    for url in company_links:
        if 'Overview' in url:
            urls_scraped_51to200.append(url) #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE ##

    #click "Next"
    next_button = driver.find_element_by_xpath('//*[@id="ReactCompanyExplorePageContainer"]/div/div/div/div/div[3]/div/ul/li[7]/button')
    next_button.click()
    time.sleep(10)

# %%
print(len(urls_scraped_51to200))
urls_scraped_51to200
# Out:
# 605
# ['https://www.glassdoor.com/Overview/Working-at-Zaxby-s-EI_IE26617.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Radio-Flyer-EI_IE6864.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-PamTen-EI_IE278002.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Next-Century-EI_IE728677.11,23.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Achieve-Today-EI_IE816503.11,24.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Zaxby-s-EI_IE26617.11,18.htm',
#  'https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Radio-Flyer-EI_IE6864.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at
11,26.htm',
 'https://www.glassdoor.com/Overview/Working-at-eAssist-EI_IE814561.11,18.htm']

# %%
unsuccessful_links_51to200 = [] ####################################################
companies_51to200 = [] #############################################################

#iterating through each company's "Overview" url
for url in urls_scraped_51to200: ################################################
    try: #fail safe for inevitable errors
        driver.get(url)
        time.sleep(5)

##---------------------------- Gathering Variables - Main Page ---------------------------------##                                
        name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
        size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
        headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
        industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
        try:
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
        except: 
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

    #Gather Description - handling "Read More" button
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
            read_more.click()
            time.sleep(2)
            description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
        except:
            description = "N/A"

    #Gather Mission - handling "Read More" button    
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
            read_more.click()
            time.sleep(2)
            mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
        except:
            mission = "N/A"

##-------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
    #Webpage layout 1
        try: 
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
            time.sleep(5) #let page load

            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
    #Webpage layout 2
        except: 
            driver.get(url) #recalling url
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
            time.sleep(5) #let page load
            
            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                
##---------------------------------- Creating a Dictionary ----------------------------------------##
        companies_51to200.append({ ####################################################
            "NAME" : name,
            "SIZE" : size,
            "LOCATION_HQ" : headquarters,
            "INDUSTRY" : industry,
            "RATING_OVERALL" : rating_overall,
            "RATING_DI" : rating_DI,
            "RATING_CV" : rating_CV,
            "RATING_WL" : rating_WL,
            "RATING_SM" : rating_SM,
            "RATING_CB" : rating_CB,
            "RATING_CO" : rating_CO,
            "NUM_REVIEWS" : num_reviews,
            "DESCRIPTION" : description,
            "MISSION" : mission
                         })

    except: #fail safe for inevitable errors
        unsuccessful_links_51to200.append(url) #adding unsuccessful urls to a list ##########
        print('ERROR: ', url)
        time.sleep(10)
    
    print(f'Finished scraping {len(companies_51to200)} companies') #########################
    #Save dataframe:
    df_51to200 = pd.DataFrame(companies_51to200) ###############################################
    df_51to200 = df_51to200.to_csv('data/glassdoor_ratings_51to200.csv', index=False) ################
print(f'Finished scraping {len(companies_51to200)} companies') ##############################
# Out:
# Finished scraping 1 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm
# Finished scraping 1 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Radio-Flyer-EI_IE6864.11,22.htm
# Finished scraping 1 companies
# Finished scraping 2 companies
# Finished scraping 3 companies
# Finished scraping 4 companies
# Finished scraping 5 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm
# Finished scraping 5 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Radio-Flyer-EI_IE6864.11,22.htm
# Finished scraping 5 companies
# Finished scraping 6 companies
# Finished scraping 7 companies
# Finished scraping 8 companies
# Finished scraping 9 companies
# Finished scraping 10 companies
# Finished scraping 11 companies
# Finished scraping 12 companies
# Finished scraping 13 companies
# Finished scraping 14 companies
# Finished scraping 15 companies
# ...

# %%
print(len(companies_51to200))
print('unsuccessful: ', len(unsuccessful_links_51to200))
unsuccessful_links_51to200
# Out:
# 566
# unsuccessful:  39
# ['https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Radio-Flyer-EI_IE6864.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Radio-Flyer-EI_IE6864.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Citi-EI_IE8843.11,15.htm',
#  'https://www.glassdoor.com/Overview/Working-at-EY-EI_IE2784.11,13.htm',
#  'https://www.glassdoor.com/Overview/Working-at-The-Home-Depot-EI_IE655.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Target-EI_IE194.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-European-Wax-Center-EI_IE397347.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Radio-Flyer-EI_IE6864.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-TCG-Inc-EI_IE331765.11,18.htm',
# ...

# %%
df_51to200

# %%
pd.read_csv('data/glassdoor_ratings_51to200.csv')
# Out:
#                                       NAME                 SIZE  \
# 0                    Zaxby's\nHiring Surge  51 to 200 Employees
# 1                                   PamTen  51 to 200 Employees
# 2                             Next Century  51 to 200 Employees
# 3                            Achieve Today  51 to 200 Employees
# 4                    Zaxby's\nHiring Surge  51 to 200 Employees
# ..                                     ...                  ...
# 561                                Virbela  51 to 200 Employees
# 562                                 Allego  51 to 200 Employees
# 563  Applewood Plumbing Heating & Electric  51 to 200 Employees
# 564                        ISPA Technology  51 to 200 Employees
# 565                                eAssist  51 to 200 Employees
#
#                 LOCATION_HQ                               INDUSTRY  \
# 0                Athens, GA  Fast-Food & Quick-Service Restaurants
# ...

# %%
driver.close()
driver.quit()

# %% [markdown]
# # Company size: 1-50

# %%
while len(urls_scraped_1to50)<500:
    #scrape page for urls
    elems = driver.find_elements_by_tag_name('a') #find links on an individual search page tagged with the 'a' tag

    #list of all links on page
    company_links = [] #all links
    for elem in elems:
        company_link = elem.get_attribute('href') #returns every item with 'href' attribute (these are the links for each company)
        company_links.append(company_link)
        #iterating through each company's "Overview" url
    for url in company_links:
        if 'Overview' in url:
            urls_scraped_1to50.append(url) #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE #### UPDATE VALUE ##

    #click "Next"
    next_button = driver.find_element_by_xpath('//*[@id="ReactCompanyExplorePageContainer"]/div/div/div/div/div[3]/div/ul/li[7]/button')
    next_button.click()
    time.sleep(3)

# %%
print(len(urls_scraped_1to50))
urls_scraped_1to50
# Out:
# 503
# ['https://www.glassdoor.com/Overview/Working-at-Mathnasium-EI_IE245646.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Push-Agency-EI_IE349846.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Horizon-Innovations-EI_IE713903.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Traveling-Vineyard-EI_IE403511.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-OLN-EI_IE330005.11,14.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Naughty-Dog-EI_IE134488.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-SV-Academy-EI_IE1958536.11,21.htm',
#  'https://www.glassdoor.com/Overview/Working-at-EAI-Technologies-EI_IE261943.11,27.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Capstone-Consultants-EI_IE417802.11,31.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Tekstrom-EI_IE276815.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Prestige-NY-EI_IE819962.11,22.htm',
# ...

# %% [markdown]
# **Create 1-50 dataframe:**

# %%
unsuccessful_links_1to50 = [] ####################################################
companies_1to50 = [] #############################################################

#iterating through each company's "Overview" url
for url in urls_scraped_1to50: ################################################
    try: #fail safe for inevitable errors
        driver.get(url)
        time.sleep(5)

##---------------------------------- Handling login ------------------------------------------##
#         name = 'n' # <---- ENTER GLASSDOOR CREDENTIALS HERE
#         pw = 'pw'
        
#         try: #login                    
#             username = driver.find_element_by_id("userEmail")
#             password = driver.find_element_by_id("userPassword")
#             submit = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div[2]/div/div[1]/div[3]/form/div[3]/div[1]/button')
#             username.send_keys(name)
#             password.send_keys(pw)
#             submit.click()
#             time.sleep(4) #let page load
#         except: #no login required
#             time.sleep(2)
#             pass

##---------------------------- Gathering Variables - Main Page ---------------------------------##                                
        name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
        size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
        headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
        industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
        try:
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
        except: 
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

    #Gather Description - handling "Read More" button
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
            read_more.click()
            time.sleep(2)
            description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
        except:
            description = "N/A"

    #Gather Mission - handling "Read More" button    
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
            read_more.click()
            time.sleep(2)
            mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
        except:
            mission = "N/A"

##-------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
    #Webpage layout 1
        try: 
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
            time.sleep(5) #let page load

            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
    #Webpage layout 2
        except: 
            driver.get(url) #recalling url
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
            time.sleep(5) #let page load
            
            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                
##---------------------------------- Creating a Dictionary ----------------------------------------##
        companies_1to50.append({ ####################################################
            "NAME" : name,
            "SIZE" : size,
            "LOCATION_HQ" : headquarters,
            "INDUSTRY" : industry,
            "RATING_OVERALL" : rating_overall,
            "RATING_DI" : rating_DI,
            "RATING_CV" : rating_CV,
            "RATING_WL" : rating_WL,
            "RATING_SM" : rating_SM,
            "RATING_CB" : rating_CB,
            "RATING_CO" : rating_CO,
            "NUM_REVIEWS" : num_reviews,
            "DESCRIPTION" : description,
            "MISSION" : mission
                         })

    except: #fail safe for inevitable errors
        unsuccessful_links_1to50.append(url) #adding unsuccessful urls to a list ##########
        print('ERROR: ', url)
        time.sleep(10)
    
    print(f'Finished scraping {len(companies_1to50)} companies') #########################
    #Save dataframe:
    df_1to50 = pd.DataFrame(companies_1to50) ###############################################
    df_1to50 = df_1to50.to_csv('data/glassdoor_ratings_1to50.csv', index=False) ################
print(f'Finished scraping {len(companies_1to50)} companies') ##############################
# Out:
# Finished scraping 1 companies
# Finished scraping 2 companies
# Finished scraping 3 companies
# Finished scraping 4 companies
# Finished scraping 5 companies
# Finished scraping 6 companies
# Finished scraping 7 companies
# Finished scraping 8 companies
# Finished scraping 9 companies
# Finished scraping 10 companies
# Finished scraping 11 companies
# Finished scraping 12 companies
# Finished scraping 13 companies
# Finished scraping 14 companies
# Finished scraping 15 companies
# Finished scraping 16 companies
# Finished scraping 17 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-New-Age-Marketing-Inc-EI_IE884710.11,32.htm
# Finished scraping 17 companies
# Finished scraping 18 companies
# Finished scraping 19 companies
# Finished scraping 20 companies
# Finished scraping 21 companies
# Finished scraping 22 companies
# Finished scraping 23 companies
# Finished scraping 24 companies
# Finished scraping 25 companies
# Finished scraping 26 companies
# ...

# %%
print(len(companies_1to50))
print('unsuccessful: ', len(unsuccessful_links_1to50))
unsuccessful_links_1to50
# Out:
# 493
# unsuccessful:  10
# ['https://www.glassdoor.com/Overview/Working-at-New-Age-Marketing-Inc-EI_IE884710.11,32.htm',
#  'https://www.glassdoor.com/Overview/Working-at-CRM-Science-EI_IE1317695.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-CRM-Science-EI_IE1317695.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Diligent-Services-EI_IE1172998.11,28.htm',
#  'https://www.glassdoor.com/Overview/Working-at-J-P-Systems-EI_IE733722.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Designity-EI_IE1592078.11,20.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Designity-EI_IE1592078.11,20.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Ridge-Zeller-Therapy-EI_IE1316375.11,31.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Ketamine-Clinics-of-Los-Angeles-EI_IE1059385.11,42.htm',
#  'https://www.glassdoor.com/Overview/Working-at-WalkThrough-EI_IE1521867.11,22.htm']

# %%
pd.read_csv('data/glassdoor_ratings_1to50.csv')
# Out:
#                       NAME               SIZE             LOCATION_HQ  \
# 0               Mathnasium  1 to 50 Employees         Los Angeles, CA
# 1              Push Agency  1 to 50 Employees               Tempe, AZ
# 2      Horizon Innovations  1 to 50 Employees        Jacksonville, FL
# 3       Traveling Vineyard  1 to 50 Employees             Ipswich, MA
# 4                      OLN  1 to 50 Employees          Long Beach, CA
# ..                     ...                ...                     ...
# 488          King of Maids  1 to 50 Employees              Skokie, IL
# 489         Goldwater Bank  1 to 50 Employees          Scottsdale, AZ
# 490         Genesys Talent  1 to 50 Employees             Houston, TX
# 491    G2 Capital Advisors  1 to 50 Employees              Boston, MA
# 492  Avenues International  1 to 50 Employees  Princeton Junction, NJ
#
#                                   INDUSTRY  RATING_OVERALL  RATING_DI  \
# ...

# %%
driver.close()
driver.quit()

# %% [markdown]
# # Company size: 5001-10k
# urls_scraped_5kto10k

# %%
print(len(urls_scraped))
urls_scraped
# Out:
# 506
# ['https://www.glassdoor.com/Overview/Working-at-Northwestern-University-EI_IE3919.11,34.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Patni-Computer-Systems-EI_IE17328.11,33.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Vanderbilt-University-EI_IE3034.11,32.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Biogen-EI_IE1336.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Zillow-EI_IE40802.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Manpower-EI_IE2548.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-University-of-Illinois-at-Chicago-EI_IE149533.11,44.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Autodesk-EI_IE1155.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Capital-Group-EI_IE9441.11,24.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Rutgers-University-EI_IE22285.11,29.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Washington-State-University-EI_IE33500.11,38.htm',
# ...

# %%
#assigning urls_scraped to new variable - urls_scraped_5kto10k
urls_scraped_5kto10k = ['https://www.glassdoor.com/Overview/Working-at-Northwestern-University-EI_IE3919.11,34.htm',
 'https://www.glassdoor.com/Overview/Working-at-Patni-Computer-Systems-EI_IE17328.11,33.htm',
 'https://www.glassdoor.com/Overview/Working-at-Vanderbilt-University-EI_IE3034.11,32.htm',
 'https://www.glassdoor.com/Overview/Working-at-Biogen-EI_IE1336.11,17.htm',
 'https://www.glassdoor.com/Overview/Working-at-Zillow-EI_IE40802.11,17.htm',
 'https://www.glassdoor.com/Overview/Working-at-Manpower-EI_IE2548.11,19.htm',
 'https://www.glassdoor.com/Overview/Working-at-University-of-Illinois-at-Chicago-EI_IE149533.11,44.htm',
 'https://www.glassdoor.com/Overview/Working-at-Autodesk-EI_IE1155.11,19.htm',
 'https://www.glassdoor.com/Overview/Working-at-Capital-Group-EI_IE9441.11,24.htm',
 'https://www.glassdoor.com/Overview/Working-at-Rutgers-University-EI_IE22285.11,29.htm',
 'https://www.glassdoor.com/Overview/Working-at-Washington-State-University-EI_IE33500.11,38.htm',
 'https://www.glassdoor.com/Overview/Working-at-REI-EI_IE7319.11,14.htm',
 'https://www.glassdoor.com/Overview/Working-at-Indiana-University-EI_IE2840.11,29.htm',
 'https://www.glassdoor.com/Overview/Working-at-Netflix-EI_IE11891.11,18.htm',
 'https://www.glassdoor.com/Overview/Working-at-Yahoo-EI_IE5807.11,16.htm',
 'https://www.glassdoor.com/Overview/Working-at-Boston-Children-s-Hospital-EI_IE18645.11,37.htm',
 'https://www.glassdoor.com/Overview/Working-at-Airbnb-EI_IE391850.11,17.htm',
 'https://www.glassdoor.com/Overview/Working-at-AMD-EI_IE15.11,14.htm',
 'https://www.glassdoor.com/Overview/Working-at-SpaceX-EI_IE40371.11,17.htm',
 'https://www.glassdoor.com/Overview/Working-at-Temple-University-EI_IE23406.11,28.htm',
 'https://www.glassdoor.com/Overview/Working-at-IHG-Hotels-and-Resorts-EI_IE4232.11,33.htm',
 'https://www.glassdoor.com/Overview/Working-at-Chick-fil-A-EI_IE5873.11,22.htm',
 'https://www.glassdoor.com/Overview/Working-at-Fannie-Mae-EI_IE247.11,21.htm',
 'https://www.glassdoor.com/Overview/Working-at-Freddie-Mac-EI_IE1585.11,22.htm',
 'https://www.glassdoor.com/Overview/Working-at-U-S-Cellular-EI_IE1048.11,23.htm',
 'https://www.glassdoor.com/Overview/Working-at-Johns-Hopkins-Medicine-EI_IE4658.11,33.htm',
 'https://www.glassdoor.com/Overview/Working-at-Illumina-EI_IE11671.11,19.htm',
 'https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm',
 'https://www.glassdoor.com/Overview/Working-at-Regeneron-Pharmaceuticals-EI_IE981.11,36.htm',
 'https://www.glassdoor.com/Overview/Working-at-Regeneron-Pharmaceuticals-EI_IE981.11,36.htm',
 'https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm',
 'https://www.glassdoor.com/Overview/Working-at-KLA-EI_IE1557.11,14.htm',
 'https://www.glassdoor.com/Overview/Working-at-Northwestern-Medicine-EI_IE120846.11,32.htm',
 'https://www.glassdoor.com/Overview/Working-at-QuikTrip-EI_IE2947.11,19.htm',
 'https://www.glassdoor.com/Overview/Working-at-Electronic-Arts-EI_IE1628.11,26.htm',
 'https://www.glassdoor.com/Overview/Working-at-Citrix-EI_IE5432.11,17.htm',
 'https://www.glassdoor.com/Overview/Working-at-Warner-Bros-EI_IE13195.11,22.htm',
 'https://www.glassdoor.com/Overview/Working-at-VIPKid-EI_IE1105111.11,17.htm',
 'https://www.glassdoor.com/Overview/Working-at-ZS-Associates-EI_IE115506.11,24.htm',
 'https://www.glassdoor.com/Overview/Working-at-Juniper-Networks-EI_IE7224.11,27.htm',
 'https://www.glassdoor.com/Overview/Working-at-athenahealth-EI_IE18207.11,23.htm',
 'https://www.glassdoor.com/Overview/Working-at-Grant-Thornton-EI_IE100134.11,25.htm',
 'https://www.glassdoor.com/Overview/Working-at-Lyft-EI_IE700614.11,15.htm',
 'https://www.glassdoor.com/Overview/Working-at-Brigham-and-Women-s-Hospital-EI_IE20213.11,39.htm',
 'https://www.glassdoor.com/Overview/Working-at-FactSet-EI_IE6066.11,18.htm',
 'https://www.glassdoor.com/Overview/Working-at
 'https://www.glassdoor.com/Overview/Working-at-Day-and-Zimmermann-EI_IE2760.11,29.htm',
 'https://www.glassdoor.com/Overview/Working-at-Maimonides-Medical-Center-EI_IE19825.11,36.htm',
 'https://www.glassdoor.com/Overview/Working-at-Massachusetts-Department-of-Transportation-EI_IE305870.11,53.htm']

# %% [markdown]
# #### Now time to scarpe each url for dictionary

# %%
unsuccessful_links_5kto10k = [] ####################################################
companies_5kto10k = [] #############################################################

#iterating through each company's "Overview" url
for url in urls_scraped_5kto10k: ################################################
    try: #fail safe for inevitable errors
        driver.get(url)
        time.sleep(5)

##---------------------------- Gathering Variables - Main Page ---------------------------------##                                
        name = driver.find_element_by_xpath('//*[@id="EmpHeroAndEmpInfo"]/div[3]/div[2]').text
        size = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[3]/div').text
        headquarters = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[2]/div').text
        industry = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/ul/li[6]/div').text
        try:
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[3]/a').text
        except: 
            num_reviews = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[3]/a').text        

    #Gather Description - handling "Read More" button
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class 
            read_more.click()
            time.sleep(2)
            description = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[1]/span').text
        except:
            description = "N/A"

    #Gather Mission - handling "Read More" button    
        try:
            read_more = driver.find_element_by_class_name('css-1tgo67c.e16x8fv00') #button class
            read_more.click()
            time.sleep(2)
            mission = driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[1]/div[2]').text
        except:
            mission = "N/A"

##-------------------------- Gathering Variables - Ratings Pop-up --------------------------------##    
    #Webpage layout 1
        try: 
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[3]/div[1]/div[2]').click()
            time.sleep(5) #let page load

            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
    #Webpage layout 2
        except: 
            driver.get(url) #recalling url
            driver.find_element_by_xpath('//*[@id="EIOverviewContainer"]/div/div[4]/div[1]/div[2]').click()
            time.sleep(5) #let page load
            
            rating_overall = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[1]/div/div[3]').text
            rating_DI = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[3]/div/div[3]').text
            rating_CV = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/div/div[3]').text
            rating_WL = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[4]/div/div[3]').text
            rating_SM = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[5]/div/div[3]').text
            rating_CB = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[6]/div/div[3]').text
            rating_CO = driver.find_element_by_xpath('//*[@id="reviewDetailsModal"]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[7]/div/div[3]').text

            time.sleep(np.random.choice([x/10 for x in range(7,22)])) #some time to rest 
                                
##---------------------------------- Creating a Dictionary ----------------------------------------##
        companies_5kto10k.append({ ####################################################
            "NAME" : name,
            "SIZE" : size,
            "LOCATION_HQ" : headquarters,
            "INDUSTRY" : industry,
            "RATING_OVERALL" : rating_overall,
            "RATING_DI" : rating_DI,
            "RATING_CV" : rating_CV,
            "RATING_WL" : rating_WL,
            "RATING_SM" : rating_SM,
            "RATING_CB" : rating_CB,
            "RATING_CO" : rating_CO,
            "NUM_REVIEWS" : num_reviews,
            "DESCRIPTION" : description,
            "MISSION" : mission
                         })

    except: #fail safe for inevitable errors
        unsuccessful_links_5kto10k.append(url) #adding unsuccessful urls to a list ##########
        print('ERROR: ', url)
        time.sleep(10)
    
    print(f'Finished scraping {len(companies_5kto10k)} companies') #########################
    #Save dataframe:
    df_5kto10k = pd.DataFrame(companies_5kto10k) ###############################################
    df_5kto10k = df_5kto10k.to_csv('data/glassdoor_ratings_5kto10k.csv', index=False) ################
print(f'Finished scraping {len(companies_5kto10k)} companies') ##############################
# Out:
# Finished scraping 1 companies
# Finished scraping 2 companies
# Finished scraping 3 companies
# Finished scraping 4 companies
# Finished scraping 5 companies
# Finished scraping 6 companies
# Finished scraping 7 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Autodesk-EI_IE1155.11,19.htm
# Finished scraping 7 companies
# Finished scraping 8 companies
# Finished scraping 9 companies
# Finished scraping 10 companies
# Finished scraping 11 companies
# Finished scraping 12 companies
# Finished scraping 13 companies
# Finished scraping 14 companies
# Finished scraping 15 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Airbnb-EI_IE391850.11,17.htm
# Finished scraping 15 companies
# Finished scraping 16 companies
# Finished scraping 17 companies
# Finished scraping 18 companies
# Finished scraping 19 companies
# ERROR:  https://www.glassdoor.com/Overview/Working-at-Chick-fil-A-EI_IE5873.11,22.htm
# Finished scraping 19 companies
# ...

# %%
print(len(companies_5kto10k))
print('unsuccessful: ', len(unsuccessful_links_5kto10k))
unsuccessful_links_5kto10k
# Out:
# 452
# unsuccessful:  54
# ['https://www.glassdoor.com/Overview/Working-at-Autodesk-EI_IE1155.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Airbnb-EI_IE391850.11,17.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Chick-fil-A-EI_IE5873.11,22.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Illumina-EI_IE11671.11,19.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Juniper-Networks-EI_IE7224.11,27.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Cellular-Sales-EI_IE152005.11,25.htm',
#  'https://www.glassdoor.com/Overview/Working-at-GE-Healthcare-EI_IE4112.11,24.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Aflac-EI_IE1302.11,16.htm',
#  'https://www.glassdoor.com/Overview/Working-at-Avaya-EI_IE12121.11,16.htm',
# ...

# %%
pd.read_csv('data/glassdoor_ratings_5kto10k.csv')
# Out:
#                                                   NAME  \
# 0                              Northwestern University
# 1            Patni Computer Systems\nAcquired by IGATE
# 2                                Vanderbilt University
# 3                                               Biogen
# 4                                               Zillow
# ..                                                 ...
# 447  Prestige Senior Living/Prestige Care\nHiring S...
# 448                                     American Water
# 449                                   Day & Zimmermann
# 450                          Maimonides Medical Center
# 451         Massachusetts Department of Transportation
#
#                         SIZE       LOCATION_HQ  \
# 0    5001 to 10000 Employees      Evanston, IL
# 1    5001 to 10000 Employees     Mumbai, India
# 2    5001 to 10000 Employees     Nashville, TN
# 3    5001 to 10000 Employees     Cambridge, MA
# 4    5001 to 10000 Employees       Seattle, WA
# ...

# %%
driver.close()
driver.quit()

# %% [markdown]
# # Previous try 5k

# %%
unsuccessful_links5k_1 = ['https://www.glassdoor.com/Overview/Working-at-Patni-Computer-Systems-EI_IE17328.11,33.htm',
    'https://www.glassdoor.com/Overview/Working-at-Autodesk-EI_IE1155.11,19.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Airbnb-EI_IE391850.11,17.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Illumina-EI_IE11671.11,19.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Northwestern-Mutual-EI_IE2919.11,30.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Juniper-Networks-EI_IE7224.11,27.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Cellular-Sales-EI_IE152005.11,25.htm', 
    'https://www.glassdoor.com/Overview/Working-at-GE-Healthcare-EI_IE4112.11,24.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Aflac-EI_IE1302.11,16.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Avaya-EI_IE12121.11,16.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Rackspace-Technology-EI_IE11783.11,31.htm', 
    'https://www.glassdoor.com/Overview/Working-at-MITRE-EI_IE3976.11,16.htm', 
    'https://www.glassdoor.com/Overview/Working-at-Edelman-EI_IE4608.11,18.htm', 
    'https://www.glassdoor.com/Overview/Working-at-